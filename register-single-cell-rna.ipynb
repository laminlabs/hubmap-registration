# %% [markdown]
# # Register single-cell RNA-seq datasets

# %%
import lamindb as ln
import bionty as bt
import wetlab as wl

ln.track("WrlPTZWhrZZP0001")
# Out:
# → connected lamindb: laminlabs/hubmap
# → loaded Transform('WrlPTZWhrZZP0001'), re-started Run('XCvmcC6e...') at 2025-01-29 09:26:09 UTC
# → notebook imports: bionty==1.0.0 fsspec==2024.9.0 lamindb==1.0.5 wetlab==1.0.1

# %%
# Corresponds to the curated metadata not the raw API output
metadata = ln.Artifact.get("Z8sZr9vMHjY5WjqL0001").load()

# %%
# The table contains a bit of ATAC. Here we only focus on (sc-)RNA-seq and add the ATAC later.
scrna_seq_only = metadata[metadata["dataset_type"] == "RNAseq"]

# %%
from fsspec.asyn import FSTimeoutError

for idx, row in scrna_seq_only.iterrows():
    ds = row.to_dict()

    try:
        # Some rows do not have URLs. These are high level dataset views that may have metadata.
        artifacts = []
        if url := ds["raw_expr_url"]:
            raw_af = ln.Artifact(url, description=f"{ds['title']}").save()
            raw_af.ulabels.add(ln.ULabel.filter(name="raw").one())
            artifacts.append(raw_af)

        if sec_url := ds["secondary_analysis_url"]:
            sec_af = ln.Artifact(sec_url, description=f"{ds['title']}").save()
            sec_af.ulabels.add(ln.ULabel.filter(name="secondary").one())
            artifacts.append(sec_af)

        if scv_url := ds["scvelo_url"]:
            scv_af = ln.Artifact(scv_url, description=f"{ds['title']}").save()
            scv_af.ulabels.add(ln.ULabel.filter(name="scvelo").one())
            artifacts.append(scv_af)

        if expr_url := ds["expr_url"]:
            expr_af = ln.Artifact(expr_url, description=f"{ds['title']}").save()
            expr_af.ulabels.add(ln.ULabel.filter(name="expr").one())
            artifacts.append(expr_af)

            expr_af.references.add(ln.Reference.filter(doi=ds["doi"]).one())
            expr_af.tissues.add(bt.Tissue.filter(name=ds["tissue"]).one())
            expr_af.ethnicities.add(bt.Ethnicity.filter(name=ds["ethnicity"]).one())
            expr_af.phenotypes.add(bt.Phenotype.filter(name=ds["sex"]).one())
            for disease_name in ds["diseases"]:
                expr_af.diseases.add(bt.Disease.filter(name=disease_name).one())
            expr_af.ulabels.add(ln.ULabel.filter(name=ds["suspension_type"]).one())
            expr_af.experimental_factors.add(
                bt.ExperimentalFactor.filter(name=ds["assay"]).one()
            )
            expr_af.donors.add(wl.Donor.filter(name=ds["donor_id"]).one())
            expr_af.biosamples.add(wl.Biosample.filter(name=ds["sample_id"]).one())
            expr_af.ulabels.add(ln.ULabel.filter(name="tissue").one())

        ds_cl = ln.Collection.filter(key=ds["collection_uuid"]).one_or_none()
        if ds_cl:
            ds_cl.artifacts.add(*artifacts)
        elif artifacts:
            ds_cl = ln.Collection(
                artifacts, key=ds["collection_uuid"], description=ds["title"]
            ).save()
    except FSTimeoutError:
        print(
            f"Timeout error for: {ds['title']} of collection UUID {ds['collection_uuid']}"
        )
        continue
# Out:
# → returning existing artifact with same hash: Artifact(uid='AzqCWQAKLMV3iTMA0000', is_latest=True, key='f6eb890063d13698feb11d39fa61e45a/raw_expr.h5ad', description='RNAseq data from the small intestine of a 67.0-year-old white female', suffix='.h5ad', otype='AnnData', size=67867992, hash='of_TeLP6cet2JBj3o_kZmQ', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:16:35 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='fWN781TxuZibkBOR0000', is_latest=True, key='f6eb890063d13698feb11d39fa61e45a/secondary_analysis.h5ad', description='RNAseq data from the small intestine of a 67.0-year-old white female', suffix='.h5ad', otype='AnnData', size=888111371, hash='ian3P5CN68AAvoDMC6sZLw', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:16:39 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='enXVzwjw4voS8UCb0000', is_latest=True, key='f6eb890063d13698feb11d39fa61e45a/expr.h5ad', description='RNAseq data from the small intestine of a 67.0-year-old white female', suffix='.h5ad', otype='AnnData', size=139737320, hash='kR476u81gwXI6rEbXzNBvQ', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:16:43 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='nDAh2laO88anX8Q70000', is_latest=True, key='391061b538480d6d630bdfec283c0293/raw_expr.h5ad', description='RNAseq data from the spleen of a 18.0-year-old white male', suffix='.h5ad', otype='AnnData', size=35068240, hash='_XHUwmmuRg_6RQ8HlykFdQ', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:17:05 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='W0uhVNqGfJLlHnCM0000', is_latest=True, key='391061b538480d6d630bdfec283c0293/secondary_analysis.h5ad', description='RNAseq data from the spleen of a 18.0-year-old white male', suffix='.h5ad', otype='AnnData', size=290848206, hash='fRo_huzcyG7rxekadUpCvA', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:17:09 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='a63pi6V7ALgYVvx50000', is_latest=True, key='391061b538480d6d630bdfec283c0293/expr.h5ad', description='RNAseq data from the spleen of a 18.0-year-old white male', suffix='.h5ad', otype='AnnData', size=74892984, hash='D8gJupkmP452-HNBDusp-Q', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:17:13 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='Nuts4jiNgjLXaAZE0000', is_latest=True, key='71477f504b0069828a368009fa3ab1ad/raw_expr.h5ad', description='RNAseq data from the large intestine of a 24.0-year-old white female', suffix='.h5ad', otype='AnnData', size=37099668, hash='h2w98cGIkxMfFVz8uOYgLQ', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:17:31 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='Io8FlZ6J1t1Cucw00000', is_latest=True, key='71477f504b0069828a368009fa3ab1ad/secondary_analysis.h5ad', description='RNAseq data from the large intestine of a 24.0-year-old white female', suffix='.h5ad', otype='AnnData', size=207164698, hash='mD_znb6mP0jJQRQhCa9-fA', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:17:36 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='WlKTUjk4YWZoP7YN0000', is_latest=True, key='71477f504b0069828a368009fa3ab1ad/expr.h5ad', description='RNAseq data from the large intestine of a 24.0-year-old white female', suffix='.h5ad', otype='AnnData', size=73825240, hash='wl53h3XWi_Wdd91ddRM9Fw', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:17:40 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='bEH4orHbRmaymzWQ0000', is_latest=True, key='a5729f859fc944c76f77fc74a1710e3b/raw_expr.h5ad', description='RNAseq data from the large intestine of a 24.0-year-old white female', suffix='.h5ad', otype='AnnData', size=111950008, hash='gqy5H2aNFRbev2AeeWe67w', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:17:58 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='SOUZluAJSLsUcKmY0000', is_latest=True, key='a5729f859fc944c76f77fc74a1710e3b/secondary_analysis.h5ad', description='RNAseq data from the large intestine of a 24.0-year-old white female', suffix='.h5ad', otype='AnnData', size=1072234072, hash='kwlwCrli-Qp_tKGqy4aR0Q', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:18:02 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='dzPbcXTZpex9tDyO0000', is_latest=True, key='a5729f859fc944c76f77fc74a1710e3b/expr.h5ad', description='RNAseq data from the large intestine of a 24.0-year-old white female', suffix='.h5ad', otype='AnnData', size=232046408, hash='AlUjzeDvOg7dAYcI0WDX6w', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:18:06 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='sj5ARZNWPObFZLcS0000', is_latest=True, key='f2647d9533956fdb12da6b1fc6254441/raw_expr.h5ad', description='RNAseq data from the large intestine of a 24.0-year-old white female', suffix='.h5ad', otype='AnnData', size=67855968, hash='Jv5JudZAw4LajazwD6Xw8w', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:18:26 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='itOkaHlVZXakh2k40000', is_latest=True, key='f2647d9533956fdb12da6b1fc6254441/secondary_analysis.h5ad', description='RNAseq data from the large intestine of a 24.0-year-old white female', suffix='.h5ad', otype='AnnData', size=397677313, hash='D7TwG1_tH0d3jTAQi5J3mA', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:18:31 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='BDZxZ3e5AolO2qZK0000', is_latest=True, key='f2647d9533956fdb12da6b1fc6254441/expr.h5ad', description='RNAseq data from the large intestine of a 24.0-year-old white female', suffix='.h5ad', otype='AnnData', size=138884776, hash='eufsK5NnQj7v1VNPEfr_sQ', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:18:35 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='WT6xO8mO8zIlqMmA0000', is_latest=True, key='5e2aaccdea5c209e217888f2c20ea64b/raw_expr.h5ad', description='RNAseq data from the small intestine of a 38.0-year-old white male', suffix='.h5ad', otype='AnnData', size=17945328, hash='7_vYP5Wg9SgVUd-xfbNcug', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:18:54 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='Bu08ztWosLlltIeR0000', is_latest=True, key='5e2aaccdea5c209e217888f2c20ea64b/secondary_analysis.h5ad', description='RNAseq data from the small intestine of a 38.0-year-old white male', suffix='.h5ad', otype='AnnData', size=156578110, hash='QvHLKY3mbTnrFRKFl70utw', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:18:58 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='xhKvirEnfp5eSDlW0000', is_latest=True, key='5e2aaccdea5c209e217888f2c20ea64b/expr.h5ad', description='RNAseq data from the small intestine of a 38.0-year-old white male', suffix='.h5ad', otype='AnnData', size=27988072, hash='HbJ5nG7F67ac1Sr8R2mfhg', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:19:02 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='12oxb0d2s8vhWirk0000', is_latest=True, key='de78115cc476af9422f916ddfbccbfb6/raw_expr.h5ad', description='RNAseq data from the heart of a 43.0-year-old white male', suffix='.h5ad', otype='AnnData', size=41093344, hash='O6D8q9GrhRtoTnwOVipw5A', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:19:19 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='SEWTzD1SzAueUxv50000', is_latest=True, key='de78115cc476af9422f916ddfbccbfb6/secondary_analysis.h5ad', description='RNAseq data from the heart of a 43.0-year-old white male', suffix='.h5ad', otype='AnnData', size=705642400, hash='F1poWKDxbz5CZNAbXqVylQ', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:19:23 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='8vI4IIOE7A8AF1RQ0000', is_latest=True, key='de78115cc476af9422f916ddfbccbfb6/expr.h5ad', description='RNAseq data from the heart of a 43.0-year-old white male', suffix='.h5ad', otype='AnnData', size=79395600, hash='Rg1v2dGTPQESV3PGxh2mlw', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:19:27 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='vkZ8mAgi8qMoSJ7m0000', is_latest=True, key='9e91d1be412466551533cce5594450cb/raw_expr.h5ad', description='RNAseq data from the heart of a 53.0-year-old white male', suffix='.h5ad', otype='AnnData', size=34233472, hash='mo4AYpAtS0a3guu_l1NS2g', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:19:46 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='Uqb3Q1MqGBsenxlt0000', is_latest=True, key='9e91d1be412466551533cce5594450cb/secondary_analysis.h5ad', description='RNAseq data from the heart of a 53.0-year-old white male', suffix='.h5ad', otype='AnnData', size=554944013, hash='wr9ydrucLH6lq8Nq-kCNWQ', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:19:50 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='FRZV4NNzxD9TQIwu0000', is_latest=True, key='9e91d1be412466551533cce5594450cb/expr.h5ad', description='RNAseq data from the heart of a 53.0-year-old white male', suffix='.h5ad', otype='AnnData', size=64005968, hash='BEiI0lkHQWsx19KQGmLXmA', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:19:54 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='97h75W8lRACemHFT0000', is_latest=True, key='c6bb00096b0cf40751f9d6003fb730c7/raw_expr.h5ad', description='RNAseq data from the heart of a 51.0-year-old white male', suffix='.h5ad', otype='AnnData', size=48716432, hash='dt7EcuB-scgVZIhF_MfqLA', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:20:14 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='UYIXD7oTpyojypXk0000', is_latest=True, key='c6bb00096b0cf40751f9d6003fb730c7/secondary_analysis.h5ad', description='RNAseq data from the heart of a 51.0-year-old white male', suffix='.h5ad', otype='AnnData', size=878563142, hash='I-PD-5Zzbm6AnCo8cIa43w', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:20:19 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='vr6bIRML527tPi8j0000', is_latest=True, key='c6bb00096b0cf40751f9d6003fb730c7/expr.h5ad', description='RNAseq data from the heart of a 51.0-year-old white male', suffix='.h5ad', otype='AnnData', size=96669168, hash='pj0tKvU1BoYzS3JecxAbgQ', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:20:23 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='5i6sEG3DSlw55io20000', is_latest=True, key='87e85403e3f7a946fc40bdcf5cba8360/raw_expr.h5ad', description='RNAseq data from the large intestine of a 37.0-year-old white male', suffix='.h5ad', otype='AnnData', size=103479816, hash='mG6XRE5Gi5IP7qG5z1eAiQ', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:20:43 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='xLpZLf3cfqjLFMzz0000', is_latest=True, key='87e85403e3f7a946fc40bdcf5cba8360/secondary_analysis.h5ad', description='RNAseq data from the large intestine of a 37.0-year-old white male', suffix='.h5ad', otype='AnnData', size=1107837826, hash='3SqEhNy89FAmot70G-SxOg', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:20:46 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='SyaC5dZwIQ8eRIIS0000', is_latest=True, key='87e85403e3f7a946fc40bdcf5cba8360/expr.h5ad', description='RNAseq data from the large intestine of a 37.0-year-old white male', suffix='.h5ad', otype='AnnData', size=212024920, hash='B9IZ2X83Co6lh4Gm39Y3Ig', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:20:50 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='UkuW3SChdHdlFVSw0000', is_latest=True, key='898138b7f45a67c574e9955fb400e9be/raw_expr.h5ad', description='RNAseq data from the kidney (left) of a 40.0-year-old white female', suffix='.h5ad', otype='AnnData', size=32304048, hash='3PcS07cemiJ9SRK-LeNYbA', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:21:10 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='rtI6kJOAGdPtaeSI0000', is_latest=True, key='898138b7f45a67c574e9955fb400e9be/secondary_analysis.h5ad', description='RNAseq data from the kidney (left) of a 40.0-year-old white female', suffix='.h5ad', otype='AnnData', size=349536118, hash='Ae9_WmFlWKhK6AftPYSjRw', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:21:14 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='NzaOTvzAkTFzGjhf0000', is_latest=True, key='898138b7f45a67c574e9955fb400e9be/expr.h5ad', description='RNAseq data from the kidney (left) of a 40.0-year-old white female', suffix='.h5ad', otype='AnnData', size=57766952, hash='RyMM7ecv6Bt1p_LaI7xGRA', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:21:18 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='QRyogqZsfIsTQyGb0000', is_latest=True, key='266d58d22549461cd454c32084b9f7fe/raw_expr.h5ad', description='RNAseq data from the small intestine of a 37.0-year-old white male', suffix='.h5ad', otype='AnnData', size=132060080, hash='MZU29uwyvAkDULpNiknPLA', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:21:36 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='2YlGVjTiB6MHt7Vh0000', is_latest=True, key='266d58d22549461cd454c32084b9f7fe/secondary_analysis.h5ad', description='RNAseq data from the small intestine of a 37.0-year-old white male', suffix='.h5ad', otype='AnnData', size=847728326, hash='hQ5GFQfkwcoyvhlhAJnw8g', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:21:41 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='e1ZZkhcl2ED8QHey0000', is_latest=True, key='266d58d22549461cd454c32084b9f7fe/expr.h5ad', description='RNAseq data from the small intestine of a 37.0-year-old white male', suffix='.h5ad', otype='AnnData', size=274040680, hash='sA4SU7QTF1srayMoNBkmkg', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:21:45 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='AQnLMC70ln9THHZM0000', is_latest=True, key='39d51c436734e5750bf84553ef7eaf85/raw_expr.h5ad', description='RNAseq data from the large intestine of a 37.0-year-old white male', suffix='.h5ad', otype='AnnData', size=139607648, hash='LxPYz16uAiaA5lmU6iTGEg', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:22:05 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='bRsIdX8qm2Dl7opj0000', is_latest=True, key='39d51c436734e5750bf84553ef7eaf85/secondary_analysis.h5ad', description='RNAseq data from the large intestine of a 37.0-year-old white male', suffix='.h5ad', otype='AnnData', size=1012271077, hash='MXlIuaiETx8bqTcpqMuu3A', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:22:09 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='iYaw4ZwGD1ywYdvf0000', is_latest=True, key='39d51c436734e5750bf84553ef7eaf85/expr.h5ad', description='RNAseq data from the large intestine of a 37.0-year-old white male', suffix='.h5ad', otype='AnnData', size=286580456, hash='k4gadlwFvBwpRiz-Puukvg', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:22:12 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='P81YoGUd7tT3zvIQ0000', is_latest=True, key='4b5dc6d04aa30a6eb0b224a7ab7d03b3/raw_expr.h5ad', description='RNAseq data from the kidney (left) of a 25.0-year-old white female', suffix='.h5ad', otype='AnnData', size=85528128, hash='EPcSwJft98bOmYy8jZdV4g', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:22:33 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='whdKLF54yeMEkn2m0000', is_latest=True, key='4b5dc6d04aa30a6eb0b224a7ab7d03b3/secondary_analysis.h5ad', description='RNAseq data from the kidney (left) of a 25.0-year-old white female', suffix='.h5ad', otype='AnnData', size=
', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:28:57 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='FEhU0rzhYqv1aTaj0000', is_latest=True, key='bbcad31a55b1710dd5f889be8f63b62b/raw_expr.h5ad', description='RNAseq data from the kidney (right) of a 54.0-year-old white male', suffix='.h5ad', otype='AnnData', size=120038016, hash='BDDFD1BihPIPSpEztMYMlg', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:28:00 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='fgTRYauu4GQZzI5Y0000', is_latest=True, key='bbcad31a55b1710dd5f889be8f63b62b/secondary_analysis.h5ad', description='RNAseq data from the kidney (right) of a 54.0-year-old white male', suffix='.h5ad', otype='AnnData', size=2802125279, hash='_7dU1GRn4_lHPu-cY5YB5A', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:28:04 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='Gs8REyNwpamWNvBl0000', is_latest=True, key='bbcad31a55b1710dd5f889be8f63b62b/expr.h5ad', description='RNAseq data from the kidney (right) of a 54.0-year-old white male', suffix='.h5ad', otype='AnnData', size=244369048, hash='H33LpYksUx0QQVRMVQZjAQ', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:28:08 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='8OQylsFfGPbwTljK0000', is_latest=True, key='aa93e53df10842c13348a334c8fe423f/raw_expr.h5ad', description='RNAseq data from the kidney (left) of a 45.0-year-old white female', suffix='.h5ad', otype='AnnData', size=189439840, hash='iOLQ49KSZt_cwLEqhZQrLw', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:30:07 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='ggE2i0xTeRUXPrTL0000', is_latest=True, key='aa93e53df10842c13348a334c8fe423f/secondary_analysis.h5ad', description='RNAseq data from the kidney (left) of a 45.0-year-old white female', suffix='.h5ad', otype='AnnData', size=4346981639, hash='R3K9n7Dbd0aSnj0ymgKyTw', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:30:11 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='j2mVqjDWKZsy5kmf0000', is_latest=True, key='aa93e53df10842c13348a334c8fe423f/expr.h5ad', description='RNAseq data from the kidney (left) of a 45.0-year-old white female', suffix='.h5ad', otype='AnnData', size=391422072, hash='r-ExBbFBOa7FFUVSF2GSIA', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:30:15 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='FIHbwnfO2aBKVKQh0000', is_latest=True, key='ac1d4544ab4886b851f74b2c21952378/raw_expr.h5ad', description='RNAseq data from the kidney (left) of a 45.0-year-old white female', suffix='.h5ad', otype='AnnData', size=215343408, hash='fKW9keJi3ZID1Pi5I8eyHA', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:30:36 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='rBNt9pZjjSpmyxFg0000', is_latest=True, key='ac1d4544ab4886b851f74b2c21952378/secondary_analysis.h5ad', description='RNAseq data from the kidney (left) of a 45.0-year-old white female', suffix='.h5ad', otype='AnnData', size=3018757727, hash='QyDBolsC_LrXsH6NPx8-yw', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:30:40 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='vSRbzKRDru83xoVf0000', is_latest=True, key='ac1d4544ab4886b851f74b2c21952378/expr.h5ad', description='RNAseq data from the kidney (left) of a 45.0-year-old white female', suffix='.h5ad', otype='AnnData', size=451608456, hash='3piNi7FdKxFzfy7cddHJuQ', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:30:44 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='FIHbwnfO2aBKVKQh0000', is_latest=True, key='ac1d4544ab4886b851f74b2c21952378/raw_expr.h5ad', description='RNAseq data from the kidney (left) of a 45.0-year-old white female', suffix='.h5ad', otype='AnnData', size=215343408, hash='fKW9keJi3ZID1Pi5I8eyHA', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:30:36 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# ...
# → returning existing artifact with same hash: Artifact(uid='rTKIUr5ifuv5BlO20000', is_latest=True, key='6cd63d0ee2c67c3be41e4be1522d9c07/raw_expr.h5ad', description='RNAseq data from the kidney (left) of a 76.0-year-old white male', suffix='.h5ad', otype='AnnData', size=97665232, hash='ozi4j8BgYs7t1pNH-twqNw', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 16:30:49 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='JyNMq1iokAHPHIge0000', is_latest=True, key='6cd63d0ee2c67c3be41e4be1522d9c07/secondary_analysis.h5ad', description='RNAseq data from the kidney (left) of a 76.0-year-old white male', suffix='.h5ad', otype='AnnData', size=1142018474, hash='8RbojbBpdwq2J9YGrKuf_w', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 16:30:52 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='gHiT9vv6SyfBlczM0000', is_latest=True, key='6cd63d0ee2c67c3be41e4be1522d9c07/expr.h5ad', description='RNAseq data from the kidney (left) of a 76.0-year-old white male', suffix='.h5ad', otype='AnnData', size=197293576, hash='ngB7p7H_6Vs_ervilKKWFw', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 16:30:56 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='dEM0OrJocY1drVUA0000', is_latest=True, key='aaedb5272190e61bf557d3b0a1bc591f/raw_expr.h5ad', description='RNAseq data from the kidney (right) of a 29.0-year-old white male', suffix='.h5ad', otype='AnnData', size=18259360, hash='vlNgQapIooBQ_ZCR9Jv8Qw', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 16:31:11 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='wpeZW2e6FdZtbYa10000', is_latest=True, key='d1e9f509063984326570cf603c5654f2/raw_expr.h5ad', description='RNAseq data from the kidney (left) of a 76.0-year-old white male', suffix='.h5ad', otype='AnnData', size=92939168, hash='rs9NdaPXXpTewkGjWubBUA', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:34:45 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='pxND52Yr64NceH120000', is_latest=True, key='d1e9f509063984326570cf603c5654f2/secondary_analysis.h5ad', description='RNAseq data from the kidney (left) of a 76.0-year-old white male', suffix='.h5ad', otype='AnnData', size=1325225881, hash='7Zr8GmPJZsy-RDyJ6HS2TA', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:34:49 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='bdVS1xWPNn2AC94j0000', is_latest=True, key='d1e9f509063984326570cf603c5654f2/expr.h5ad', description='RNAseq data from the kidney (left) of a 76.0-year-old white male', suffix='.h5ad', otype='AnnData', size=182895864, hash='XlJp0ksMqpb65u3YhiZJjQ', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:34:53 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='wpeZW2e6FdZtbYa10000', is_latest=True, key='d1e9f509063984326570cf603c5654f2/raw_expr.h5ad', description='RNAseq data from the kidney (left) of a 76.0-year-old white male', suffix='.h5ad', otype='AnnData', size=92939168, hash='rs9NdaPXXpTewkGjWubBUA', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:34:45 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='pxND52Yr64NceH120000', is_latest=True, key='d1e9f509063984326570cf603c5654f2/secondary_analysis.h5ad', description='RNAseq data from the kidney (left) of a 76.0-year-old white male', suffix='.h5ad', otype='AnnData', size=1325225881, hash='7Zr8GmPJZsy-RDyJ6HS2TA', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:34:49 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='bdVS1xWPNn2AC94j0000', is_latest=True, key='d1e9f509063984326570cf603c5654f2/expr.h5ad', description='RNAseq data from the kidney (left) of a 76.0-year-old white male', suffix='.h5ad', otype='AnnData', size=182895864, hash='XlJp0ksMqpb65u3YhiZJjQ', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:34:53 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='wpeZW2e6FdZtbYa10000', is_latest=True, key='d1e9f509063984326570cf603c5654f2/raw_expr.h5ad', description='RNAseq data from the kidney (left) of a 76.0-year-old white male', suffix='.h5ad', otype='AnnData', size=92939168, hash='rs9NdaPXXpTewkGjWubBUA', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:34:45 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='pxND52Yr64NceH120000', is_latest=True, key='d1e9f509063984326570cf603c5654f2/secondary_analysis.h5ad', description='RNAseq data from the kidney (left) of a 76.0-year-old white male', suffix='.h5ad', otype='AnnData', size=1325225881, hash='7Zr8GmPJZsy-RDyJ6HS2TA', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:34:49 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='bdVS1xWPNn2AC94j0000', is_latest=True, key='d1e9f509063984326570cf603c5654f2/expr.h5ad', description='RNAseq data from the kidney (left) of a 76.0-year-old white male', suffix='.h5ad', otype='AnnData', size=182895864, hash='XlJp0ksMqpb65u3YhiZJjQ', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:34:53 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='3GVlPXKS55hxCpyj0000', is_latest=True, key='9457860c1b69f7ec3e51a6b648eabf13/raw_expr.h5ad', description='RNAseq data from the kidney (left) of a 76.0-year-old white male', suffix='.h5ad', otype='AnnData', size=260088416, hash='pn-oMAtK_SxxXgvWPx9urQ', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:34:17 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='jcptMQqo1CQN87UV0000', is_latest=True, key='9457860c1b69f7ec3e51a6b648eabf13/secondary_analysis.h5ad', description='RNAseq data from the kidney (left) of a 76.0-year-old white male', suffix='.h5ad', otype='AnnData', size=3931243866, hash='q9cJ2cntxx_N0LhlykglAA', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:34:22 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='5R9lPYjCKKddSzfP0000', is_latest=True, key='9457860c1b69f7ec3e51a6b648eabf13/expr.h5ad', description='RNAseq data from the kidney (left) of a 76.0-year-old white male', suffix='.h5ad', otype='AnnData', size=547799544, hash='KlqSkuG5wm_UMIYODSOQBA', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:34:26 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='tLFzwEbqm5Z2udev0000', is_latest=True, key='dd648e4648238b25a7d1062669ea89af/raw_expr.h5ad', description='RNAseq data from the lung (right) of a 37.0-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=308247600, hash='93-jSfpBozQxwjxzWGexHg', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:35:59 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='kS53Ho99HUAT6nLq0000', is_latest=True, key='dd648e4648238b25a7d1062669ea89af/secondary_analysis.h5ad', description='RNAseq data from the lung (right) of a 37.0-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=10710021375, hash='2ddok1h1fkgMU2rS0z3wYA', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:36:03 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='NaDOx7OQZDLz9Wjl0000', is_latest=True, key='dd648e4648238b25a7d1062669ea89af/expr.h5ad', description='RNAseq data from the lung (right) of a 37.0-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=645427592, hash='i1bJgKgVQCeiB5WOVWwi7w', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:36:07 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='tLFzwEbqm5Z2udev0000', is_latest=True, key='dd648e4648238b25a7d1062669ea89af/raw_expr.h5ad', description='RNAseq data from the lung (right) of a 37.0-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=308247600, hash='93-jSfpBozQxwjxzWGexHg', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:35:59 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='kS53Ho99HUAT6nLq0000', is_latest=True, key='dd648e4648238b25a7d1062669ea89af/secondary_analysis.h5ad', description='RNAseq data from the lung (right) of a 37.0-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=10710021375, hash='2ddok1h1fkgMU2rS0z3wYA', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:36:03 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='NaDOx7OQZDLz9Wjl0000', is_latest=True, key='dd648e4648238b25a7d1062669ea89af/expr.h5ad', description='RNAseq data from the lung (right) of a 37.0-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=645427592, hash='i1bJgKgVQCeiB5WOVWwi7w', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:36:07 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='1YvKqJL4NLH4IZbf0000', is_latest=True, key='d171ff8d83f707ecca64ff159c7160a7/raw_expr.h5ad', description='RNAseq data from the lung (right) of a 37.0-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=379025216, hash='DRxkiV9VXNvHV6Kb3JqGrA', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:49:17 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='QSvnPpwILfmB1xfb0000', is_latest=True, key='d171ff8d83f707ecca64ff159c7160a7/secondary_analysis.h5ad', description='RNAseq data from the lung (right) of a 37.0-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=12533101889, hash='yFl2WQPCx_fls7fPjJ13wg', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:49:21 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='LN38ZR1kHw3PgSoe0000', is_latest=True, key='d171ff8d83f707ecca64ff159c7160a7/expr.h5ad', description='RNAseq data from the lung (right) of a 37.0-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=781371800, hash='dwgrYYeVxKiza9ZyQmzYRg', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:49:25 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='1YvKqJL4NLH4IZbf0000', is_latest=True, key='d171ff8d83f707ecca64ff159c7160a7/raw_expr.h5ad', description='RNAseq data from the lung (right) of a 37.0-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=379025216, hash='DRxkiV9VXNvHV6Kb3JqGrA', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:49:17 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='QSvnPpwILfmB1xfb0000', is_latest=True, key='d171ff8d83f707ecca64ff159c7160a7/secondary_analysis.h5ad', description='RNAseq data from the lung (right) of a 37.0-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=12533101889, hash='yFl2WQPCx_fls7fPjJ13wg', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:49:21 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='LN38ZR1kHw3PgSoe0000', is_latest=True, key='d171ff8d83f707ecca64ff159c7160a7/expr.h5ad', description='RNAseq data from the lung (right) of a 37.0-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=781371800, hash='dwgrYYeVxKiza9ZyQmzYRg', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:49:25 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='dRqZdmo2ZkgE6IxN0000', is_latest=True, key='4369a119a9c06ea304003a5c3cb3a2e0/raw_expr.h5ad', description='RNAseq data from the lung (right) of a 37.0-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=533019728, hash='x2GmGQojxtY1edPv1axRoA', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:51:31 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='HcH4VIlNJ2po9dK60000', is_latest=True, key='4369a119a9c06ea304003a5c3cb3a2e0/secondary_analysis.h5ad', description='RNAseq data from the lung (right) of a 37.0-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=16454289087, hash='nwRZdXHE21bZcXCsXZuI3A', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:51:37 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='LQtOxyQ1dmN5HjGt0000', is_latest=True, key='4369a119a9c06ea304003a5c3cb3a2e0/expr.h5ad', description='RNAseq data from the lung (right) of a 37.0-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=1105885288, hash='tuSfcbrnTsvBQ6HLwHBf5A', space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:51:41 UTC); if you intended to query to track this artifact as an input, use: ln.Artifact.get()
# Timeout error for UUID: RNAseq data from the kidney (left) of a 65.0-year-old white male

# %%
ln.finish()
# Out:
# • please hit CTRL + s to save the notebook in your editor .. ✓
# → finished Run('XCvmcC6e') after 1h at 2025-01-29 11:11:55 UTC
# → go to: https://lamin.ai/laminlabs/hubmap/transform/WrlPTZWhrZZP0001
# → to update your notebook from the CLI, run: lamin save /home/lukas/code/hubmap_registration/register_single_cell_rna.ipynb
