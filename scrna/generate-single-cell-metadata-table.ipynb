# %% [markdown]
# # Generate single-cell metadata table

# %%
# !lamin connect laminlabs/hubmap
# Out:
# → connected lamindb: laminlabs/hubmap

# %%
from query import get_dataset_info, get_dataset_urls, scRNAseqDataset
from datetime import datetime, timezone

from rich.progress import (
    Progress,
    SpinnerColumn,
    TimeElapsedColumn,
    BarColumn,
    TextColumn,
)

import lamindb as ln
import pandas as pd
# Out:
# → connected lamindb: laminlabs/hubmap

# %%
ln.track("oWI9cCguyzHn0005")
# Out:
# → created Transform('oWI9cCguyzHn0005'), started new Run('vArdZ4aF...') at 2025-01-31 11:51:24 UTC
# → notebook imports: lamindb==1.0.5 pandas==2.2.3 query rich==13.9.4

# %%
# Use the HubMAP metadata table that was downloaded using the UI button for all datasets
df = pd.read_csv(ln.Artifact.get("9G4UaeVKSY0zy7SX0000").cache(), sep="\t")

# Include all assays here for which we want to get metadata information
# We included a few RNA + ATAC assays here but just registered single-cell RNA-seq for now
single_cell_assays = [
    "SNARE-seq2",
    "SNARE2-RNAseq",
    "snRNAseq-10xGenomics-v3",
    "snRNAseq",
    "scRNAseq-10xGenomics",
    "scRNAseq-10xGenomics-v3",
    "sciRNAseq",
    "scRNAseq-10xGenomics-v2",
]
hubmap_sc_only = df[df["assay_type"].isin(single_cell_assays)]

# %%
def create_hubmap_metadata_df(hubmap_metadata: pd.DataFrame):
    data = []
    with Progress(
        SpinnerColumn(),
        TextColumn("[progress.description]{task.description}"),
        BarColumn(),
        TextColumn("[progress.percentage]{task.percentage:>3.0f}%"),
        TextColumn("[blue]{task.fields[uuid]}"),
        TimeElapsedColumn(),
    ) as progress:
        """Fetches dataset URLs and metadata using the API to collect it in a DataFrame."""
        task = progress.add_task(
            "[cyan]Processing datasets...", total=len(hubmap_metadata), uuid=""
        )
        for uuid in hubmap_metadata["uuid"].values:
            progress.update(task, uuid=uuid)
            dataset_info = get_dataset_info(uuid)[0]
            donor_metadata = (
                dataset_info.get("donor", {})
                .get("metadata", {})
                .get("organ_donor_data", [])
            )

            dataset_urls = get_dataset_urls(
                uuid,
                file_types=[
                    "raw_expr.h5ad",
                    "expr.h5ad",
                    "secondary_analysis.h5ad",
                    "scvelo.h5ad",
                ],
                dataset_class=scRNAseqDataset,
            )
            urls = {
                "raw_expr_url": dataset_urls.raw_expr or "",
                "expr_url": dataset_urls.expr or "",
                "secondary_analysis_url": dataset_urls.secondary_analysis or "",
                "scvelo_url": dataset_urls.scvelo or "",
            }

            row = {
                "assay": hubmap_metadata.loc[
                    hubmap_metadata["uuid"] == uuid, "assay_type"
                ].iloc[0],
                "rnaseq_assay_method": hubmap_metadata.loc[
                    hubmap_metadata["uuid"] == uuid, "rnaseq_assay_method"
                ].iloc[0],
                "title": dataset_info.get("title", ""),
                "group_name": dataset_info.get("group_name", ""),
                "consortium": "HuBMAP",
                "doi": dataset_info.get("registered_doi", ""),
                "publication_date": datetime.fromtimestamp(
                    dataset_info.get("published_timestamp", 0) / 1000, tz=timezone.utc
                ).strftime("%Y-%m-%d")
                if dataset_info.get("published_timestamp")
                else "",
                "status": dataset_info.get("data_access_level", ""),
                "dataset_type": dataset_info.get("dataset_type", ""),
                "processing": "raw",
                "organ": next(
                    (
                        sample.get("organ", "")
                        for sample in dataset_info.get("origin_samples", [])
                        if sample.get("organ")
                    ),
                    "",
                ),
                "sample_category": next(
                    (
                        sample.get("sample_category", "")
                        for sample in dataset_info.get("source_samples", [])
                        if sample.get("sample_category")
                    ),
                    "",
                ),
                "analyte_class": next(
                    (
                        a
                        for a in [
                            "RNA",
                            "Protein",
                            "DNA",
                            "Metabolite",
                            "Lipid",
                            "Nucleic acid + protein",
                            "Endogenous fluorophore",
                            "Polysaccharide",
                            "Peptide",
                            "DNA + RNA",
                            "Lipid + metabolite",
                        ]
                        if a in dataset_info.get("dataset_type", "")
                        or any(
                            a in d.get("dataset_type", "")
                            for d in dataset_info.get("descendants", [])
                        )
                    ),
                    "",
                ),
                "bmi": next(
                    (
                        item.get("data_value", "")
                        for item in donor_metadata
                        if item.get("grouping_concept_preferred_term")
                        == "Body Mass Index"
                    ),
                    "",
                ),
                "age": next(
                    (
                        item.get("data_value", "")
                        for item in donor_metadata
                        if item.get("grouping_concept_preferred_term") == "Age"
                    ),
                    "",
                ),
                "ethnicity": next(
                    (
                        item.get("data_value", "")
                        for item in donor_metadata
                        if item.get("grouping_concept_preferred_term") == "Race"
                    ),
                    "",
                ),
                "sex": next(
                    (
                        item.get("data_value", "")
                        for item in donor_metadata
                        if item.get("grouping_concept_preferred_term") == "Sex"
                    ),
                    "",
                ),
                "diseases": [
                    item.get("data_value", "")
                    for item in donor_metadata
                    if item.get("grouping_concept_preferred_term") == "Medical History"
                ]
                or ["normal"],
                "donor_id": dataset_info.get("donor", {}).get("hubmap_id", ""),
                "sample_id": next(
                    (
                        sample.get("hubmap_id", "")
                        for sample in dataset_info.get("source_samples", [])
                        if sample.get("hubmap_id")
                    ),
                    "",
                ),
                "collection_uuid": dataset_info.get("immediate_ancestor_ids", [])[0]
                if dataset_info.get("immediate_ancestor_ids")
                else "",  # Always the first ancestor ID
                **urls,
            }
            data.append(row)
            progress.update(task, advance=1)

    df = pd.DataFrame(data, index=hubmap_metadata["uuid"].values)
    df.index.name = "uuid"

    return df

# %%
single_cell_metadata_df = create_hubmap_metadata_df(hubmap_sc_only)
single_cell_metadata_df
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                     assay  \
# uuid
# a5234e06fed9a14ee8d29c5aa0258ba5     scRNAseq-10xGenomics
# c03acf2de0caff5e5850e0f76d555e1b     scRNAseq-10xGenomics
# 8776e9183d5f85d90535a0b1b3b4e32a     scRNAseq-10xGenomics
# b29f62452b8e333ffc62d2e69caa18fa                 snRNAseq
# 20ee458e5ee361717b68ca72caf6044e  snRNAseq-10xGenomics-v3
# ...                                                   ...
# c45049b3115ed7c8d39f7ec3b0a06020  scRNAseq-10xGenomics-v3
# 13fe2b69c62dc2c3bbe43c9177973033  snRNAseq-10xGenomics-v3
# 18ec0bb859d2a0422b68f2f6491a7e15  snRNAseq-10xGenomics-v3
# 976144220fb6be94f1f71298062f0bda  snRNAseq-10xGenomics-v3
# 555eaeb0e58682538a5bbdc2af2f9bd0  snRNAseq-10xGenomics-v3
#
#                                                                 rnaseq_assay_method  \
# uuid
# a5234e06fed9a14ee8d29c5aa0258ba5                                  Single Cell 3' v3
# c03acf2de0caff5e5850e0f76d555e1b                                  Single Cell 3' v3
# 8776e9183d5f85d90535a0b1b3b4e32a                                  Single Cell 3' v3
# b29f62452b8e333ffc62d2e69caa18fa                                                 3`
# 20ee458e5ee361717b68ca72caf6044e      10x Chromium Single Cell 3' Reagent Kits v3.1
# ...                                                                             ...
# c45049b3115ed7c8d39f7ec3b0a06020  Chromium Single Cell 3' GEM, Library & Gel Bea...
# 13fe2b69c62dc2c3bbe43c9177973033                               snRNAseq-10Xgenomics
# 18ec0bb859d2a0422b68f2f6491a7e15                               snRNAseq-10Xgenomics
# 976144220fb6be94f1f71298062f0bda                               snRNAseq-10Xgenomics
# 555eaeb0e58682538a5bbdc2af2f9bd0                 10x Chromium multiome Reagent Kits
#
#                                                                               title  \
# uuid
# a5234e06fed9a14ee8d29c5aa0258ba5  RNAseq data from the lymph node of a 1.0-year-...
# c03acf2de0caff5e5850e0f76d555e1b  RNAseq data from the thymus of a 18.0-year-old...
# 8776e9183d5f85d90535a0b1b3b4e32a  RNAseq data from the thymus of a 18.0-year-old...
# b29f62452b8e333ffc62d2e69caa18fa  RNAseq data from the large intestine of a 67.0...
# 20ee458e5ee361717b68ca72caf6044e  RNAseq data from the small intestine of a 67.0...
# ...                                                                             ...
# c45049b3115ed7c8d39f7ec3b0a06020  RNAseq data from the knee (right) of a 24.0-ye...
# 13fe2b69c62dc2c3bbe43c9177973033  RNAseq data from the bladder of a 19.0-year-ol...
# 18ec0bb859d2a0422b68f2f6491a7e15  RNAseq data from the bladder of a 22.0-year-ol...
# 976144220fb6be94f1f71298062f0bda  RNAseq data from the bladder of a 43.0-year-ol...
# 555eaeb0e58682538a5bbdc2af2f9bd0  RNAseq data from the large intestine of a 37.0...
#
#                                                                    group_name  \
# uuid
# a5234e06fed9a14ee8d29c5aa0258ba5                    University of Florida TMC
# c03acf2de0caff5e5850e0f76d555e1b                    University of Florida TMC
# 8776e9183d5f85d90535a0b1b3b4e32a                    University of Florida TMC
# b29f62452b8e333ffc62d2e69caa18fa                                 Stanford TMC
# 20ee458e5ee361717b68ca72caf6044e                                 Stanford TMC
# ...                                                                       ...
# c45049b3115ed7c8d39f7ec3b0a06020  TMC - University of Connecticut and Scripps
# 13fe2b69c62dc2c3bbe43c9177973033       University of California San Diego TMC
# 18ec0bb859d2a0422b68f2f6491a7e15       University of California San Diego TMC
# 976144220fb6be94f1f71298062f0bda       University of California San Diego TMC
# 555eaeb0e58682538a5bbdc2af2f9bd0                                 Stanford TMC
#
#                                  consortium                       doi  \
# uuid
# a5234e06fed9a14ee8d29c5aa0258ba5     HuBMAP  10.35079/HBM252.HMBK.543
# c03acf2de0caff5e5850e0f76d555e1b     HuBMAP  10.35079/HBM457.SQKR.279
# 8776e9183d5f85d90535a0b1b3b4e32a     HuBMAP  10.35079/HBM724.ZKSM.924
# b29f62452b8e333ffc62d2e69caa18fa     HuBMAP  10.35079/HBM444.XJKC.552
# 20ee458e5ee361717b68ca72caf6044e     HuBMAP  10.35079/HBM983.LKMP.544
# ...                                     ...                       ...
# c45049b3115ed7c8d39f7ec3b0a06020     HuBMAP  10.35079/HBM629.QFBP.955
# 13fe2b69c62dc2c3bbe43c9177973033     HuBMAP  10.35079/HBM325.FBQQ.678
# 18ec0bb859d2a0422b68f2f6491a7e15     HuBMAP  10.35079/HBM449.JKGC.452
# 976144220fb6be94f1f71298062f0bda     HuBMAP  10.35079/HBM735.WZWF.739
# 555eaeb0e58682538a5bbdc2af2f9bd0     HuBMAP  10.35079/HBM659.GSQR.225
#
#                                  publication_date     status dataset_type  \
# uuid
# a5234e06fed9a14ee8d29c5aa0258ba5       2020-08-22  protected       RNAseq
# c03acf2de0caff5e5850e0f76d555e1b       2020-08-22  protected       RNAseq
# 8776e9183d5f85d90535a0b1b3b4e32a       2020-08-22  protected       RNAseq
# b29f62452b8e333ffc62d2e69caa18fa       2020-08-22  protected       RNAseq
# 20ee458e5ee361717b68ca72caf6044e       2022-11-30  protected       RNAseq
# ...                                           ...        ...          ...
# c45049b3115ed7c8d39f7ec3b0a06020       2023-12-18  protected       RNAseq
# 13fe2b69c62dc2c3bbe43c9177973033       2023-06-12  protected       RNAseq
# 18ec0bb859d2a0422b68f2f6491a7e15       2023-06-12  protected       RNAseq
# 976144220fb6be94f1f71298062f0bda       2023-06-12  protected       RNAseq
# 555eaeb0e58682538a5bbdc2af2f9bd0       2022-10-26  protected       RNAseq
#
#                                  processing organ sample_category  \
# uuid
# a5234e06fed9a14ee8d29c5aa0258ba5        raw    LY      suspension
# c03acf2de0caff5e5850e0f76d555e1b        raw    TH      suspension
# 8776e9183d5f85d90535a0b1b3b4e32a        raw    TH      suspension
# b29f62452b8e333ffc62d2e69caa18fa        raw    LI           block
# 20ee458e5ee361717b68ca72caf6044e        raw    SI           block
# ...                                     ...   ...             ...
# c45049b3115ed7c8d39f7ec3b0a06020        raw    RN           block
# 13fe2b69c62dc2c3bbe43c9177973033        raw    BL         section
# 18ec0bb859d2a0422b68f2f6491a7e15        raw    BL         section
# 976144220fb6be94f1f71298062f0bda        raw    BL         section
# 555eaeb0e58682538a5bbdc2af2f9bd0        raw    LI           block
#
#                                  analyte_class    bmi   age  \
# uuid
# a5234e06fed9a14ee8d29c5aa0258ba5           RNA  21.80   1.0
# c03acf2de0caff5e5850e0f76d555e1b           RNA  27.10  18.0
# 8776e9183d5f85d90535a0b1b3b4e32a           RNA  27.10  18.0
# b29f62452b8e333ffc62d2e69caa18fa           RNA  30.20  67.0
# 20ee458e5ee361717b68ca72caf6044e           RNA  30.20  67.0
# ...                                        ...    ...   ...
# c45049b3115ed7c8d39f7ec3b0a06020           RNA  36.90  24.0
# 13fe2b69c62dc2c3bbe43c9177973033           RNA  27.70  19.0
# 18ec0bb859d2a0422b68f2f6491a7e15           RNA         22.0
# 976144220fb6be94f1f71298062f0bda           RNA  24.70  43.0
# 555eaeb0e58682538a5bbdc2af2f9bd0           RNA  27.90  37.0
#
#                                                   ethnicity     sex  \
# uuid
# a5234e06fed9a14ee8d29c5aa0258ba5                      White    Male
# c03acf2de0caff5e5850e0f76d555e1b  Black or African American    Male
# 8776e9183d5f85d90535a0b1b3b4e32a  Black or African American    Male
# b29f62452b8e333ffc62d2e69caa18fa                      White  Female
# 20ee458e5ee361717b68ca72caf6044e                      White  Female
# ...                                                     ...     ...
# c45049b3115ed7c8d39f7ec3b0a06020                    Unknown    Male
# 13fe2b69c62dc2c3bbe43c9177973033                    Unknown    Male
# 18ec0bb859d2a0422b68f2f6491a7e15  Black or African American    Male
# 976144220fb6be94f1f71298062f0bda                      White    Male
# 555eaeb0e58682538a5bbdc2af2f9bd0                      White    Male
#
#                                                                            diseases  \
# uuid
# a5234e06fed9a14ee8d29c5aa0258ba5                                           [normal]
# c03acf2de0caff5e5850e0f76d555e1b                                           [normal]
# 8776e9183d5f85d90535a0b1b3b4e32a                                           [normal]
# b29f62452b8e333ffc62d2e69caa18fa  [Hypertension, Coronary Artery Disease, Cardia...
# 20ee458e5ee361717b68ca72caf6044e  [Hypertension, Coronary Artery Disease, Cardia...
# ...                                                                             ...
# c45049b3115ed7c8d39f7ec3b0a06020                                           [normal]
# 13fe2b69c62dc2c3bbe43c9177973033                                           [normal]
# 18ec0bb859d2a0422b68f2f6491a7e15                                           [normal]
# 976144220fb6be94f1f71298062f0bda                                           [normal]
# 555eaeb0e58682538a5bbdc2af2f9bd0                                           [normal]
#
#                                          donor_id        sample_id  \
# uuid
# a5234e06fed9a14ee8d29c5aa0258ba5  HBM638.SMWG.276  HBM789.XWDB.222
# c03acf2de0caff5e5850e0f76d555e1b  HBM678.JKBB.893  HBM363.KHLF.497
# 8776e9183d5f85d90535a0b1b3b4e32a  HBM678.JKBB.893  HBM365.LNPG.969
# b29f62452b8e333ffc62d2e69caa18fa  HBM279.WPZP.978  HBM588.GSHN.453
# 20ee458e5ee361717b68ca72caf6044e  HBM279.WPZP.978  HBM555.LQJW.397
# ...                                           ...              ...
# c45049b3115ed7c8d39f7ec3b0a06020  HBM993.XNPC.882  HBM452.VSCR.855
# 13fe2b69c62dc2c3bbe43c9177973033  HBM894.PKMC.242  HBM553.GXPD.548
# 18ec0bb859d2a0422b68f2f6491a7e15  HBM256.BRQS.425  HBM854.KCQP.863
# 976144220fb6be94f1f71298062f0bda  HBM568.HLJW.252  HBM636.WLKR.529
# 555eaeb0e58682538a5bbdc2af2f9bd0  HBM296.VWDQ.246  HBM487.LMVN.946
#
#                                                    collection_uuid  \
# uuid
# a5234e06fed9a14ee8d29c5aa0258ba5  6c717082627f452935b9f63d2d93f023
# c03acf2de0caff5e5850e0f76d555e1b  ac972fb45d1dc05548ecf400229a8038
# 8776e9183d5f85d90535a0b1b3b4e32a  268e8fb044f82a1497b5fd17918500ea
# b29f62452b8e333ffc62d2e69caa18fa  e4ee92c09a755f8889cb8c37a669e160
# 20ee458e5ee361717b68ca72caf6044e  e80cd8fab25ec8e9cb41e3872e2129c7
# ...                                                            ...
# c45049b3115ed7c8d39f7ec3b0a06020  9c63cd124b1e33aa5ea5a1f54f01f309
# 13fe2b69c62dc2c3bbe43c9177973033  a11a58186c6d136360c3d0b863b0c00c
# 18ec0bb859d2a0422b68f2f6491a7e15  a6920284fccd858507978948faca6d19
# 976144220fb6be94f1f71298062f0bda  4ff2d3993ea5aeeeb360d163ab217dc6
# 555eaeb0e58682538a5bbdc2af2f9bd0  2b269613d21a845988d12a344fa89e54
#
#                                                                        raw_expr_url  \
# uuid
# a5234e06fed9a14ee8d29c5aa0258ba5
# c03acf2de0caff5e5850e0f76d555e1b
# 8776e9183d5f85d90535a0b1b3b4e32a
# b29f62452b8e333ffc62d2e69caa18fa
# 20ee458e5ee361717b68ca72caf6044e  https://assets.hubmapconsortium.org/f6eb890063...
# ...                                                                             ...
# c45049b3115ed7c8d39f7ec3b0a06020  https://assets.hubmapconsortium.org/e4d23bbb49...
# 13fe2b69c62dc2c3bbe43c9177973033  https://assets.hubmapconsortium.org/494be31798...
# 18ec0bb859d2a0422b68f2f6491a7e15  https://assets.hubmapconsortium.org/6c57274e7a...
# 976144220fb6be94f1f71298062f0bda  https://assets.hubmapconsortium.org/d67c61063b...
# 555eaeb0e58682538a5bbdc2af2f9bd0  https://assets.hubmapconsortium.org/ff5d0d740f...
#
#                                                                            expr_url  \
# uuid
# a5234e06fed9a14ee8d29c5aa0258ba5
# c03acf2de0caff5e5850e0f76d555e1b
# 8776e9183d5f85d90535a0b1b3b4e32a
# b29f62452b8e333ffc62d2e69caa18fa
# 20ee458e5ee361717b68ca72caf6044e  https://assets.hubmapconsortium.org/f6eb890063...
# ...                                                                             ...
# c45049b3115ed7c8d39f7ec3b0a06020  https://assets.hubmapconsortium.org/e4d23bbb49...
# 13fe2b69c62dc2c3bbe43c9177973033  https://assets.hubmapconsortium.org/494be31798...
# 18ec0bb859d2a0422b68f2f6491a7e15  https://assets.hubmapconsortium.org/6c57274e7a...
# 976144220fb6be94f1f71298062f0bda  https://assets.hubmapconsortium.org/d67c61063b...
# 555eaeb0e58682538a5bbdc2af2f9bd0  https://assets.hubmapconsortium.org/ff5d0d740f...
#
#                                                              secondary_analysis_url  \
# uuid
# a5234e06fed9a14ee8d29c5aa0258ba5
# c03acf2de0caff5e5850e0f76d555e1b
# 8776e9183d5f85d90535a0b1b3b4e32a
# b29f62452b8e333ffc62d2e69caa18fa
# 20ee458e5ee361717b68ca72caf6044e  https://assets.hubmapconsortium.org/f6eb890063...
# ...                                                                             ...
# c45049b3115ed7c8d39f7ec3b0a06020  https://assets.hubmapconsortium.org/e4d23bbb49...
# 13fe2b69c62dc2c3bbe43c9177973033  https://assets.hubmapconsortium.org/494be31798...
# 18ec0bb859d2a0422b68f2f6491a7e15  https://assets.hubmapconsortium.org/6c57274e7a...
# 976144220fb6be94f1f71298062f0bda  https://assets.hubmapconsortium.org/d67c61063b...
# 555eaeb0e58682538a5bbdc2af2f9bd0  https://assets.hubmapconsortium.org/ff5d0d740f...
#
#                                  scvelo_url
# uuid
# a5234e06fed9a14ee8d29c5aa0258ba5
# c03acf2de0caff5e5850e0f76d555e1b
# 8776e9183d5f85d90535a0b1b3b4e32a
# b29f62452b8e333ffc62d2e69caa18fa
# 20ee458e5ee361717b68ca72caf6044e
# ...                                     ...
# c45049b3115ed7c8d39f7ec3b0a06020
# 13fe2b69c62dc2c3bbe43c9177973033
# 18ec0bb859d2a0422b68f2f6491a7e15
# 976144220fb6be94f1f71298062f0bda
# 555eaeb0e58682538a5bbdc2af2f9bd0
#
# [546 rows x 25 columns]

# %%
sc_af = ln.Artifact.from_df(
    single_cell_metadata_df,
    key="2024-12-20_15-35-09/meta_scrna_original.parquet",
    description="Single-cell metadata information to use for ingestion.",
).save()
# Out:
# → creating new artifact version for key='2024-12-20_15-35-09/meta_scrna_original.parquet' (storage: 's3://lamin-us-west-2/sznqFqn7xUoI')
# ... uploading ZmKRFUAwmX5RK9d80004.parquet: 100.0%
# ! The cache path /home/lukas/.cache/lamindb/lamin-us-west-2/sznqFqn7xUoI/2024-12-20_15-35-09/meta_scrna_original.parquet already exists, replacing it.

# %%
ln.finish()
# Out:
# → finished Run('vArdZ4aF') after 47m at 2025-01-31 12:38:31 UTC
# → go to: https://lamin.ai/laminlabs/hubmap/transform/oWI9cCguyzHn0005
# → to update your notebook from the CLI, run: lamin save /home/lukas/code/hubmap_registration/generate_single_cell_metadata_table.ipynb
