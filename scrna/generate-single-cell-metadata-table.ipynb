# %% [markdown]
# # Generate single-cell metadata table

# %%
import os
import sys

sys.path.append(os.path.abspath("../"))

import pandas as pd
import lamindb as ln

from query import create_hubmap_metadata_df, scRNAseqDataset

assert ln.setup.settings.instance.slug == "laminlabs/hubmap"
# Out:
# → connected lamindb: laminlabs/hubmap

# %%
ln.track("oWI9cCguyzHn0006")
# Out:
# → created Transform('oWI9cCguyzHn0006'), started new Run('osj1SMjk...') at 2025-05-12 12:43:07 UTC
# → notebook imports: lamindb==1.4.0 pandas==2.2.3 query rich==14.0.0

# %%
df = pd.read_csv(
    ln.Artifact.using("laminlabs/hubmap").get("9G4UaeVKSY0zy7SX0001").cache(), sep="\t"
)

# Include all assays here for which we want to get metadata information
single_cell_assays = [
    "scRNAseq-10xGenomics",
    "snRNAseq",
    "snRNAseq-10xGenomics-v3",
    "sciRNAseq",
    "scRNAseq-10xGenomics-v3",
    "scRNAseq-10xGenomics-v2",
]

# %%
single_cell_metadata_df = create_hubmap_metadata_df(
    df,
    file_types=[
        "raw_expr.h5ad",
        "out.h5ad",
        "expr.h5ad",
        "secondary_analysis.h5ad",
        "scvelo.h5ad",
        "scvelo_annotated.h5ad",
    ],
    dataset_class=scRNAseqDataset,
    assay_filter=single_cell_assays,
)
single_cell_metadata_df
# Out:
# Output()
# ! No usable files for uuid da93581ef554e25ec1c7a12500a56b74, HuBMAP ID HBM655.RVNL.232.
# ! No usable files for uuid 638799c2725a0c88ec7ee389cb98884f, HuBMAP ID HBM868.BXNB.448.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                     assay  \
# uuid
# 8776e9183d5f85d90535a0b1b3b4e32a     scRNAseq-10xGenomics
# c03acf2de0caff5e5850e0f76d555e1b     scRNAseq-10xGenomics
# b29f62452b8e333ffc62d2e69caa18fa                 snRNAseq
# a5234e06fed9a14ee8d29c5aa0258ba5     scRNAseq-10xGenomics
# 20ee458e5ee361717b68ca72caf6044e  snRNAseq-10xGenomics-v3
# ...                                                   ...
# f1b130f1200ae1fabe56cb506245490c                 snRNAseq
# a8652e9e3c545e61e1ffe9d54a8f1fd2                 snRNAseq
# 7277b2460f9c548004496508684a90ef  scRNAseq-10xGenomics-v2
# 4b0a0671bad77bc469ae000a66535f31                sciRNAseq
# 01844e5a048e03aa434ee0afb71c813d     scRNAseq-10xGenomics
#
#                                                             rnaseq_assay_method  \
# uuid
# 8776e9183d5f85d90535a0b1b3b4e32a                              Single Cell 3' v3
# c03acf2de0caff5e5850e0f76d555e1b                              Single Cell 3' v3
# b29f62452b8e333ffc62d2e69caa18fa                                             3`
# a5234e06fed9a14ee8d29c5aa0258ba5                              Single Cell 3' v3
# 20ee458e5ee361717b68ca72caf6044e  10x Chromium Single Cell 3' Reagent Kits v3.1
# ...                                                                         ...
# f1b130f1200ae1fabe56cb506245490c                           snRNAseq-10Xgenomics
# a8652e9e3c545e61e1ffe9d54a8f1fd2                           snRNAseq-10Xgenomics
# 7277b2460f9c548004496508684a90ef    3' end single cell RNA sequencing-bcl2fastq
# 4b0a0671bad77bc469ae000a66535f31                                      sciRNAseq
# 01844e5a048e03aa434ee0afb71c813d                              Single Cell 3' v3
#
#                                                                               title  \
# uuid
# 8776e9183d5f85d90535a0b1b3b4e32a  RNAseq data from the thymus of a 18-year-old b...
# c03acf2de0caff5e5850e0f76d555e1b  RNAseq data from the thymus of a 18-year-old b...
# b29f62452b8e333ffc62d2e69caa18fa  RNAseq data from the large intestine of a 67-y...
# a5234e06fed9a14ee8d29c5aa0258ba5  RNAseq data from the lymph node of a 1-year-ol...
# 20ee458e5ee361717b68ca72caf6044e  RNAseq data from the small intestine of a 67-y...
# ...                                                                             ...
# f1b130f1200ae1fabe56cb506245490c  RNAseq data from the kidney (right) of a 29-ye...
# a8652e9e3c545e61e1ffe9d54a8f1fd2  RNAseq data from the lung (right) of a 37-year...
# 7277b2460f9c548004496508684a90ef  RNAseq data from the liver of a 65-year-old wh...
# 4b0a0671bad77bc469ae000a66535f31  RNAseq data from the heart of a 45-year-old wh...
# 01844e5a048e03aa434ee0afb71c813d  RNAseq data from the spleen of a 21-year-old b...
#
#                                                               group_name  \
# uuid
# 8776e9183d5f85d90535a0b1b3b4e32a               University of Florida TMC
# c03acf2de0caff5e5850e0f76d555e1b               University of Florida TMC
# b29f62452b8e333ffc62d2e69caa18fa                            Stanford TMC
# a5234e06fed9a14ee8d29c5aa0258ba5               University of Florida TMC
# 20ee458e5ee361717b68ca72caf6044e                            Stanford TMC
# ...                                                                  ...
# f1b130f1200ae1fabe56cb506245490c  University of California San Diego TMC
# a8652e9e3c545e61e1ffe9d54a8f1fd2  University of California San Diego TMC
# 7277b2460f9c548004496508684a90ef                  EXT - Human Cell Atlas
# 4b0a0671bad77bc469ae000a66535f31  California Institute of Technology TMC
# 01844e5a048e03aa434ee0afb71c813d               University of Florida TMC
#
#                                  consortium                       doi  \
# uuid
# 8776e9183d5f85d90535a0b1b3b4e32a     HuBMAP  10.35079/HBM724.ZKSM.924
# c03acf2de0caff5e5850e0f76d555e1b     HuBMAP  10.35079/HBM457.SQKR.279
# b29f62452b8e333ffc62d2e69caa18fa     HuBMAP  10.35079/HBM444.XJKC.552
# a5234e06fed9a14ee8d29c5aa0258ba5     HuBMAP  10.35079/HBM252.HMBK.543
# 20ee458e5ee361717b68ca72caf6044e     HuBMAP  10.35079/HBM983.LKMP.544
# ...                                     ...                       ...
# f1b130f1200ae1fabe56cb506245490c     HuBMAP  10.35079/HBM992.XNZH.647
# a8652e9e3c545e61e1ffe9d54a8f1fd2     HuBMAP  10.35079/HBM578.ZCCJ.565
# 7277b2460f9c548004496508684a90ef     HuBMAP  10.35079/HBM596.FQNZ.472
# 4b0a0671bad77bc469ae000a66535f31     HuBMAP  10.35079/HBM725.RHWH.487
# 01844e5a048e03aa434ee0afb71c813d     HuBMAP  10.35079/HBM263.TLLN.467
#
#                                  publication_date     status dataset_type  \
# uuid
# 8776e9183d5f85d90535a0b1b3b4e32a       2020-08-22  protected       RNAseq
# c03acf2de0caff5e5850e0f76d555e1b       2020-08-22  protected       RNAseq
# b29f62452b8e333ffc62d2e69caa18fa       2020-08-22  protected       RNAseq
# a5234e06fed9a14ee8d29c5aa0258ba5       2020-08-22  protected       RNAseq
# 20ee458e5ee361717b68ca72caf6044e       2022-11-30  protected       RNAseq
# ...                                           ...        ...          ...
# f1b130f1200ae1fabe56cb506245490c       2021-06-29  protected       RNAseq
# a8652e9e3c545e61e1ffe9d54a8f1fd2       2021-06-29  protected       RNAseq
# 7277b2460f9c548004496508684a90ef       2022-03-03  protected       RNAseq
# 4b0a0671bad77bc469ae000a66535f31       2022-03-01  protected       RNAseq
# 01844e5a048e03aa434ee0afb71c813d       2021-05-02  protected       RNAseq
#
#                                  processing organ sample_category  \
# uuid
# 8776e9183d5f85d90535a0b1b3b4e32a        raw    TH      suspension
# c03acf2de0caff5e5850e0f76d555e1b        raw    TH      suspension
# b29f62452b8e333ffc62d2e69caa18fa        raw    LI           block
# a5234e06fed9a14ee8d29c5aa0258ba5        raw    LY      suspension
# 20ee458e5ee361717b68ca72caf6044e        raw    SI           block
# ...                                     ...   ...             ...
# f1b130f1200ae1fabe56cb506245490c        raw    RK         section
# a8652e9e3c545e61e1ffe9d54a8f1fd2        raw    RL         section
# 7277b2460f9c548004496508684a90ef        raw    LV      suspension
# 4b0a0671bad77bc469ae000a66535f31        raw    HT           block
# 01844e5a048e03aa434ee0afb71c813d        raw    SP      suspension
#
#                                  analyte_class   bmi age  \
# uuid
# 8776e9183d5f85d90535a0b1b3b4e32a           RNA  27.1  18
# c03acf2de0caff5e5850e0f76d555e1b           RNA  27.1  18
# b29f62452b8e333ffc62d2e69caa18fa           RNA  30.2  67
# a5234e06fed9a14ee8d29c5aa0258ba5           RNA  21.8   1
# 20ee458e5ee361717b68ca72caf6044e           RNA  30.2  67
# ...                                        ...   ...  ..
# f1b130f1200ae1fabe56cb506245490c           RNA
# a8652e9e3c545e61e1ffe9d54a8f1fd2           RNA        37
# 7277b2460f9c548004496508684a90ef           RNA  31.7  65
# 4b0a0671bad77bc469ae000a66535f31           RNA  33.1  45
# 01844e5a048e03aa434ee0afb71c813d           RNA  37.1  21
#
#                                                   ethnicity     sex  \
# uuid
# 8776e9183d5f85d90535a0b1b3b4e32a  Black or African American    Male
# c03acf2de0caff5e5850e0f76d555e1b  Black or African American    Male
# b29f62452b8e333ffc62d2e69caa18fa                      White  Female
# a5234e06fed9a14ee8d29c5aa0258ba5                      White    Male
# 20ee458e5ee361717b68ca72caf6044e                      White  Female
# ...                                                     ...     ...
# f1b130f1200ae1fabe56cb506245490c
# a8652e9e3c545e61e1ffe9d54a8f1fd2  Black or African American    Male
# 7277b2460f9c548004496508684a90ef                      White    Male
# 4b0a0671bad77bc469ae000a66535f31                      White    Male
# 01844e5a048e03aa434ee0afb71c813d  Black or African American  Female
#
#                                                                            diseases  \
# uuid
# 8776e9183d5f85d90535a0b1b3b4e32a                                           [normal]
# c03acf2de0caff5e5850e0f76d555e1b                                           [normal]
# b29f62452b8e333ffc62d2e69caa18fa  [Hypertension, Coronary Artery Disease, Cardia...
# a5234e06fed9a14ee8d29c5aa0258ba5                                           [normal]
# 20ee458e5ee361717b68ca72caf6044e  [Hypertension, Coronary Artery Disease, Cardia...
# ...                                                                             ...
# f1b130f1200ae1fabe56cb506245490c                                           [normal]
# a8652e9e3c545e61e1ffe9d54a8f1fd2                                     [Hypertension]
# 7277b2460f9c548004496508684a90ef                                           [normal]
# 4b0a0671bad77bc469ae000a66535f31                                   [Cardiac Arrest]
# 01844e5a048e03aa434ee0afb71c813d                                   [Cardiac Arrest]
#
#                                          donor_id        sample_id  \
# uuid
# 8776e9183d5f85d90535a0b1b3b4e32a  HBM678.JKBB.893  HBM365.LNPG.969
# c03acf2de0caff5e5850e0f76d555e1b  HBM678.JKBB.893  HBM363.KHLF.497
# b29f62452b8e333ffc62d2e69caa18fa  HBM279.WPZP.978  HBM588.GSHN.453
# a5234e06fed9a14ee8d29c5aa0258ba5  HBM638.SMWG.276  HBM789.XWDB.222
# 20ee458e5ee361717b68ca72caf6044e  HBM279.WPZP.978  HBM555.LQJW.397
# ...                                           ...              ...
# f1b130f1200ae1fabe56cb506245490c  HBM833.LBTG.876  HBM683.FXCD.335
# a8652e9e3c545e61e1ffe9d54a8f1fd2  HBM943.SCQQ.877  HBM282.WKTX.279
# 7277b2460f9c548004496508684a90ef  HBM796.MXZR.526  HBM285.BXQC.283
# 4b0a0671bad77bc469ae000a66535f31  HBM796.ZVVX.764  HBM797.KHRN.366
# 01844e5a048e03aa434ee0afb71c813d  HBM298.KGNJ.374  HBM769.QPWZ.976
#
#                                                        ancestor_id  \
# uuid
# 8776e9183d5f85d90535a0b1b3b4e32a  268e8fb044f82a1497b5fd17918500ea
# c03acf2de0caff5e5850e0f76d555e1b  ac972fb45d1dc05548ecf400229a8038
# b29f62452b8e333ffc62d2e69caa18fa  e4ee92c09a755f8889cb8c37a669e160
# a5234e06fed9a14ee8d29c5aa0258ba5  6c717082627f452935b9f63d2d93f023
# 20ee458e5ee361717b68ca72caf6044e  e80cd8fab25ec8e9cb41e3872e2129c7
# ...                                                            ...
# f1b130f1200ae1fabe56cb506245490c  7a3d392219da3e5fc90c9879aee9e163
# a8652e9e3c545e61e1ffe9d54a8f1fd2  27997171ea74885abbd91a99cac360d9
# 7277b2460f9c548004496508684a90ef  0d472c5ddbe96a7e29141d8c21d23fbf
# 4b0a0671bad77bc469ae000a66535f31  03947098fe5b5ec44d67ec9d65a391d5
# 01844e5a048e03aa434ee0afb71c813d  3d2bc79885fc7720f77fddd2c23f02e5
#
#                                                                        raw_expr_url  \
# uuid
# 8776e9183d5f85d90535a0b1b3b4e32a  https://assets.hubmapconsortium.org/81a9fa68b2...
# c03acf2de0caff5e5850e0f76d555e1b  https://assets.hubmapconsortium.org/e8d642084f...
# b29f62452b8e333ffc62d2e69caa18fa  https://assets.hubmapconsortium.org/c019a1cd35...
# a5234e06fed9a14ee8d29c5aa0258ba5  https://assets.hubmapconsortium.org/0576b972e0...
# 20ee458e5ee361717b68ca72caf6044e  https://assets.hubmapconsortium.org/f6eb890063...
# ...                                                                             ...
# f1b130f1200ae1fabe56cb506245490c  https://assets.hubmapconsortium.org/3bb5f743b0...
# a8652e9e3c545e61e1ffe9d54a8f1fd2  https://assets.hubmapconsortium.org/ed630484e4...
# 7277b2460f9c548004496508684a90ef  https://assets.hubmapconsortium.org/0e184744c4...
# 4b0a0671bad77bc469ae000a66535f31  https://assets.hubmapconsortium.org/b1ac71625c...
# 01844e5a048e03aa434ee0afb71c813d  https://assets.hubmapconsortium.org/d9780d3f4e...
#
#                                                                            expr_url  \
# uuid
# 8776e9183d5f85d90535a0b1b3b4e32a
# c03acf2de0caff5e5850e0f76d555e1b
# b29f62452b8e333ffc62d2e69caa18fa
# a5234e06fed9a14ee8d29c5aa0258ba5
# 20ee458e5ee361717b68ca72caf6044e  https://assets.hubmapconsortium.org/f6eb890063...
# ...                                                                             ...
# f1b130f1200ae1fabe56cb506245490c  https://assets.hubmapconsortium.org/3bb5f743b0...
# a8652e9e3c545e61e1ffe9d54a8f1fd2  https://assets.hubmapconsortium.org/ed630484e4...
# 7277b2460f9c548004496508684a90ef  https://assets.hubmapconsortium.org/0e184744c4...
# 4b0a0671bad77bc469ae000a66535f31  https://assets.hubmapconsortium.org/b1ac71625c...
# 01844e5a048e03aa434ee0afb71c813d  https://assets.hubmapconsortium.org/d9780d3f4e...
#
#                                                              secondary_analysis_url  \
# uuid
# 8776e9183d5f85d90535a0b1b3b4e32a
# c03acf2de0caff5e5850e0f76d555e1b
# b29f62452b8e333ffc62d2e69caa18fa
# a5234e06fed9a14ee8d29c5aa0258ba5
# 20ee458e5ee361717b68ca72caf6044e  https://assets.hubmapconsortium.org/f6eb890063...
# ...                                                                             ...
# f1b130f1200ae1fabe56cb506245490c  https://assets.hubmapconsortium.org/3bb5f743b0...
# a8652e9e3c545e61e1ffe9d54a8f1fd2  https://assets.hubmapconsortium.org/ed630484e4...
# 7277b2460f9c548004496508684a90ef  https://assets.hubmapconsortium.org/0e184744c4...
# 4b0a0671bad77bc469ae000a66535f31  https://assets.hubmapconsortium.org/b1ac71625c...
# 01844e5a048e03aa434ee0afb71c813d  https://assets.hubmapconsortium.org/d9780d3f4e...
#
#                                                                          scvelo_url
# uuid
# 8776e9183d5f85d90535a0b1b3b4e32a
# c03acf2de0caff5e5850e0f76d555e1b
# b29f62452b8e333ffc62d2e69caa18fa
# a5234e06fed9a14ee8d29c5aa0258ba5
# 20ee458e5ee361717b68ca72caf6044e  https://assets.hubmapconsortium.org/f6eb890063...
# ...                                                                             ...
# f1b130f1200ae1fabe56cb506245490c  https://assets.hubmapconsortium.org/3bb5f743b0...
# a8652e9e3c545e61e1ffe9d54a8f1fd2  https://assets.hubmapconsortium.org/ed630484e4...
# 7277b2460f9c548004496508684a90ef  https://assets.hubmapconsortium.org/0e184744c4...
# 4b0a0671bad77bc469ae000a66535f31  https://assets.hubmapconsortium.org/b1ac71625c...
# 01844e5a048e03aa434ee0afb71c813d  https://assets.hubmapconsortium.org/d9780d3f4e...
#
# [210 rows x 25 columns]

# %%
sc_af = ln.Artifact.from_df(
    single_cell_metadata_df,
    key="hubmap_metadata/meta_scrna_original.parquet",
    description="Single-cell metadata information to use for ingestion.",
).save()
# Out:
# → creating new artifact version for key='hubmap_metadata/meta_scrna_original.parquet' (storage: 's3://lamin-us-west-2/sznqFqn7xUoI')
# ... uploading ZmKRFUAwmX5RK9d80005.parquet: 100.0%
# ! replacing the existing cache path /Users/altananamsaraeva/Library/Caches/lamindb/lamin-us-west-2/sznqFqn7xUoI/hubmap_metadata/meta_scrna_original.parquet

# %%
ln.finish()
# Out:
# • please hit CMD + s to save the notebook in your editor  ✓
# ! cells [(1, 3), (3, None), (None, 7)] were not run consecutively
# → finished Run('osj1SMjk') after 59m at 2025-05-12 13:42:27 UTC
# → go to: https://lamin.ai/laminlabs/hubmap/transform/oWI9cCguyzHn0006
# → to update your notebook from the CLI, run: lamin save /Users/altananamsaraeva/Desktop/Lamin/hubmap-registration/scrna/generate-single-cell-metadata-table.ipynb
