# %% [markdown]
# # Register single-cell RNA-seq datasets

# %%
import lamindb as ln
import bionty as bt
import wetlab as wl
# Out:
# → connected lamindb: laminlabs/hubmap

# %%
ln.track()
# Out:
# → found notebook register-single-cell-rna.ipynb, making new version
# → created Transform('WrlPTZWhrZZP0002'), started new Run('9wCIRsb1...') at 2025-05-21 11:14:29 UTC
# → notebook imports: bionty==1.3.2 fsspec==2025.3.2 lamindb==1.5.3 wetlab==1.2.0
# • recommendation: to identify the notebook across renames, pass the uid: ln.track("WrlPTZWhrZZP")

# %%
# Corresponds to the curated metadata not the raw API output
metadata = ln.Artifact.get("Z8sZr9vMHjY5WjqL0005").load()

# %%
metadata.head()
# Out:
#                                uuid      assay  \
# 0  8776e9183d5f85d90535a0b1b3b4e32a  10x 3' v3
# 1  c03acf2de0caff5e5850e0f76d555e1b  10x 3' v3
# 2  b29f62452b8e333ffc62d2e69caa18fa  10x 3' v3
# 3  a5234e06fed9a14ee8d29c5aa0258ba5  10x 3' v3
# 4  20ee458e5ee361717b68ca72caf6044e  10x 3' v3
#
#                              rnaseq_assay_method  \
# 0                              Single Cell 3' v3
# 1                              Single Cell 3' v3
# 2                                             3`
# 3                              Single Cell 3' v3
# 4  10x Chromium Single Cell 3' Reagent Kits v3.1
#
#                                                title  \
# 0  RNAseq data from the thymus of a 18-year-old b...
# 1  RNAseq data from the thymus of a 18-year-old b...
# 2  RNAseq data from the large intestine of a 67-y...
# 3  RNAseq data from the lymph node of a 1-year-ol...
# 4  RNAseq data from the small intestine of a 67-y...
#
#                   group_name consortium                       doi  \
# 0  University of Florida TMC     HuBMAP  10.35079/HBM724.ZKSM.924
# 1  University of Florida TMC     HuBMAP  10.35079/HBM457.SQKR.279
# 2               Stanford TMC     HuBMAP  10.35079/HBM444.XJKC.552
# 3  University of Florida TMC     HuBMAP  10.35079/HBM252.HMBK.543
# 4               Stanford TMC     HuBMAP  10.35079/HBM983.LKMP.544
#
#   publication_date     status dataset_type processing organ sample_category  \
# 0       2020-08-22  protected       RNAseq        raw    TH      suspension
# 1       2020-08-22  protected       RNAseq        raw    TH      suspension
# 2       2020-08-22  protected       RNAseq        raw    LI           block
# 3       2020-08-22  protected       RNAseq        raw    LY      suspension
# 4       2022-11-30  protected       RNAseq        raw    SI           block
#
#   analyte_class   bmi age         ethnicity     sex  \
# 0           RNA  27.1  18  African American    male
# 1           RNA  27.1  18  African American    male
# 2           RNA  30.2  67          European  female
# 3           RNA  21.8   1          European    male
# 4           RNA  30.2  67          European  female
#
#                                             diseases         donor_id  \
# 0                                           [normal]  HBM678.JKBB.893
# 1                                           [normal]  HBM678.JKBB.893
# 2  [hypertensive disorder, coronary artery disord...  HBM279.WPZP.978
# 3                                           [normal]  HBM638.SMWG.276
# 4  [hypertensive disorder, coronary artery disord...  HBM279.WPZP.978
#
#          sample_id                       ancestor_id  \
# 0  HBM365.LNPG.969  268e8fb044f82a1497b5fd17918500ea
# 1  HBM363.KHLF.497  ac972fb45d1dc05548ecf400229a8038
# 2  HBM588.GSHN.453  e4ee92c09a755f8889cb8c37a669e160
# 3  HBM789.XWDB.222  6c717082627f452935b9f63d2d93f023
# 4  HBM555.LQJW.397  e80cd8fab25ec8e9cb41e3872e2129c7
#
#                                         raw_expr_url  \
# 0  https://assets.hubmapconsortium.org/81a9fa68b2...
# 1  https://assets.hubmapconsortium.org/e8d642084f...
# 2  https://assets.hubmapconsortium.org/c019a1cd35...
# 3  https://assets.hubmapconsortium.org/0576b972e0...
# 4  https://assets.hubmapconsortium.org/f6eb890063...
#
#                                             expr_url  \
# 0
# 1
# 2
# 3
# 4  https://assets.hubmapconsortium.org/f6eb890063...
#
#                               secondary_analysis_url  \
# 0
# 1
# 2
# 3
# 4  https://assets.hubmapconsortium.org/f6eb890063...
#
#                                           scvelo_url           tissue  \
# 0                                                              thymus
# 1                                                              thymus
# 2                                                     large intestine
# 3                                                          lymph node
# 4  https://assets.hubmapconsortium.org/f6eb890063...  small intestine
#
#   suspension_type tissue_type
# 0            cell      tissue
# 1            cell      tissue
# 2         nucleus      tissue
# 3            cell      tissue
# 4         nucleus      tissue

# %%
from fsspec.asyn import FSTimeoutError

for idx, row in metadata.iterrows():
    ds = row.to_dict()

    try:
        # Some rows do not have URLs. These are high level dataset views that may have metadata.
        artifacts = []

        if url := ds["raw_expr_url"]:
            raw_af = ln.Artifact(url, description=f"{ds['title']}").save()
            raw_af.ulabels.add(ln.ULabel.filter(name="raw").one())
            artifacts.append(raw_af)

        if sec_url := ds["secondary_analysis_url"]:
            sec_af = ln.Artifact(sec_url, description=f"{ds['title']}").save()
            sec_af.ulabels.add(ln.ULabel.filter(name="secondary").one())
            artifacts.append(sec_af)

        if scv_url := ds["scvelo_url"]:
            scv_af = ln.Artifact(scv_url, description=f"{ds['title']}").save()
            scv_af.ulabels.add(ln.ULabel.filter(name="scvelo").one())
            artifacts.append(scv_af)

        if expr_url := ds["expr_url"]:
            expr_af = ln.Artifact(expr_url, description=f"{ds['title']}").save()
            expr_af.ulabels.add(ln.ULabel.filter(name="expr").one())
            artifacts.append(expr_af)

            expr_af.references.add(ln.Reference.filter(doi=ds["doi"]).one())
            expr_af.tissues.add(bt.Tissue.filter(name=ds["tissue"]).one())
            expr_af.ethnicities.add(bt.Ethnicity.filter(name=ds["ethnicity"]).one())
            expr_af.phenotypes.add(bt.Phenotype.filter(name=ds["sex"]).one())
            for disease_name in ds["diseases"]:
                expr_af.diseases.add(bt.Disease.filter(name=disease_name).one())
            expr_af.ulabels.add(ln.ULabel.filter(name=ds["suspension_type"]).one())
            expr_af.experimental_factors.add(
                bt.ExperimentalFactor.filter(name=ds["assay"]).one()
            )
            expr_af.donors.add(wl.Donor.filter(name=ds["donor_id"]).one())
            expr_af.biosamples.add(wl.Biosample.filter(name=ds["sample_id"]).one())
            expr_af.ulabels.add(ln.ULabel.filter(name="tissue").one())

        ds_cl = ln.Collection.filter(key=ds["uuid"]).one_or_none()

        if ds_cl:
            ds_cl.artifacts.add(*artifacts)
        elif artifacts:
            ds_cl = ln.Collection(
                artifacts, key=ds["uuid"], description=ds["title"]
            ).save()
    except FSTimeoutError:
        print(f"Timeout error for: {ds['title']} of collection UUID {ds['uuid']}")
        continue
# Out:
# → returning existing artifact with same hash: Artifact(uid='AzqCWQAKLMV3iTMA0000', is_latest=True, key='f6eb890063d13698feb11d39fa61e45a/raw_expr.h5ad', description='RNAseq data from the small intestine of a 67-year-old white female', suffix='.h5ad', otype='AnnData', size=67867992, hash='of_TeLP6cet2JBj3o_kZmQ', n_observations=6000, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:16:35 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='fWN781TxuZibkBOR0000', is_latest=True, key='f6eb890063d13698feb11d39fa61e45a/secondary_analysis.h5ad', description='RNAseq data from the small intestine of a 67-year-old white female', suffix='.h5ad', otype='AnnData', size=888111371, hash='ian3P5CN68AAvoDMC6sZLw', n_observations=5956, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:16:39 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='enXVzwjw4voS8UCb0000', is_latest=True, key='f6eb890063d13698feb11d39fa61e45a/expr.h5ad', description='RNAseq data from the small intestine of a 67-year-old white female', suffix='.h5ad', otype='AnnData', size=139737320, hash='kR476u81gwXI6rEbXzNBvQ', n_observations=6000, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:16:43 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='nDAh2laO88anX8Q70000', is_latest=True, key='391061b538480d6d630bdfec283c0293/raw_expr.h5ad', description='RNAseq data from the spleen of a 18-year-old white male', suffix='.h5ad', otype='AnnData', size=35068240, hash='_XHUwmmuRg_6RQ8HlykFdQ', n_observations=6187, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:17:05 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='W0uhVNqGfJLlHnCM0000', is_latest=True, key='391061b538480d6d630bdfec283c0293/secondary_analysis.h5ad', description='RNAseq data from the spleen of a 18-year-old white male', suffix='.h5ad', otype='AnnData', size=290848206, hash='fRo_huzcyG7rxekadUpCvA', n_observations=3370, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:17:09 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='a63pi6V7ALgYVvx50000', is_latest=True, key='391061b538480d6d630bdfec283c0293/expr.h5ad', description='RNAseq data from the spleen of a 18-year-old white male', suffix='.h5ad', otype='AnnData', size=74892984, hash='D8gJupkmP452-HNBDusp-Q', n_observations=6187, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:17:13 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='Nuts4jiNgjLXaAZE0000', is_latest=True, key='71477f504b0069828a368009fa3ab1ad/raw_expr.h5ad', description='RNAseq data from the large intestine of a 24-year-old white female', suffix='.h5ad', otype='AnnData', size=37099668, hash='h2w98cGIkxMfFVz8uOYgLQ', n_observations=1672, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:17:31 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='Io8FlZ6J1t1Cucw00000', is_latest=True, key='71477f504b0069828a368009fa3ab1ad/secondary_analysis.h5ad', description='RNAseq data from the large intestine of a 24-year-old white female', suffix='.h5ad', otype='AnnData', size=207164698, hash='mD_znb6mP0jJQRQhCa9-fA', n_observations=1485, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:17:36 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='WlKTUjk4YWZoP7YN0000', is_latest=True, key='71477f504b0069828a368009fa3ab1ad/expr.h5ad', description='RNAseq data from the large intestine of a 24-year-old white female', suffix='.h5ad', otype='AnnData', size=73825240, hash='wl53h3XWi_Wdd91ddRM9Fw', n_observations=1672, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:17:40 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='sj5ARZNWPObFZLcS0000', is_latest=True, key='f2647d9533956fdb12da6b1fc6254441/raw_expr.h5ad', description='RNAseq data from the large intestine of a 24-year-old white female', suffix='.h5ad', otype='AnnData', size=67855968, hash='Jv5JudZAw4LajazwD6Xw8w', n_observations=3282, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:18:26 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='itOkaHlVZXakh2k40000', is_latest=True, key='f2647d9533956fdb12da6b1fc6254441/secondary_analysis.h5ad', description='RNAseq data from the large intestine of a 24-year-old white female', suffix='.h5ad', otype='AnnData', size=397677313, hash='D7TwG1_tH0d3jTAQi5J3mA', n_observations=2730, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:18:31 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='BDZxZ3e5AolO2qZK0000', is_latest=True, key='f2647d9533956fdb12da6b1fc6254441/expr.h5ad', description='RNAseq data from the large intestine of a 24-year-old white female', suffix='.h5ad', otype='AnnData', size=138884776, hash='eufsK5NnQj7v1VNPEfr_sQ', n_observations=3282, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:18:35 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='bEH4orHbRmaymzWQ0000', is_latest=True, key='a5729f859fc944c76f77fc74a1710e3b/raw_expr.h5ad', description='RNAseq data from the large intestine of a 24-year-old white female', suffix='.h5ad', otype='AnnData', size=111950008, hash='gqy5H2aNFRbev2AeeWe67w', n_observations=6000, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:17:58 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='SOUZluAJSLsUcKmY0000', is_latest=True, key='a5729f859fc944c76f77fc74a1710e3b/secondary_analysis.h5ad', description='RNAseq data from the large intestine of a 24-year-old white female', suffix='.h5ad', otype='AnnData', size=1072234072, hash='kwlwCrli-Qp_tKGqy4aR0Q', n_observations=5842, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:18:02 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='dzPbcXTZpex9tDyO0000', is_latest=True, key='a5729f859fc944c76f77fc74a1710e3b/expr.h5ad', description='RNAseq data from the large intestine of a 24-year-old white female', suffix='.h5ad', otype='AnnData', size=232046408, hash='AlUjzeDvOg7dAYcI0WDX6w', n_observations=6000, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:18:06 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='WT6xO8mO8zIlqMmA0000', is_latest=True, key='5e2aaccdea5c209e217888f2c20ea64b/raw_expr.h5ad', description='RNAseq data from the small intestine of a 38-year-old white male', suffix='.h5ad', otype='AnnData', size=17945328, hash='7_vYP5Wg9SgVUd-xfbNcug', n_observations=5998, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:18:54 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='Bu08ztWosLlltIeR0000', is_latest=True, key='5e2aaccdea5c209e217888f2c20ea64b/secondary_analysis.h5ad', description='RNAseq data from the small intestine of a 38-year-old white male', suffix='.h5ad', otype='AnnData', size=156578110, hash='QvHLKY3mbTnrFRKFl70utw', n_observations=1502, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:18:58 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='xhKvirEnfp5eSDlW0000', is_latest=True, key='5e2aaccdea5c209e217888f2c20ea64b/expr.h5ad', description='RNAseq data from the small intestine of a 38-year-old white male', suffix='.h5ad', otype='AnnData', size=27988072, hash='HbJ5nG7F67ac1Sr8R2mfhg', n_observations=5998, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:19:02 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='12oxb0d2s8vhWirk0000', is_latest=True, key='de78115cc476af9422f916ddfbccbfb6/raw_expr.h5ad', description='RNAseq data from the heart of a 43-year-old white male', suffix='.h5ad', otype='AnnData', size=41093344, hash='O6D8q9GrhRtoTnwOVipw5A', n_observations=55605, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:19:19 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='SEWTzD1SzAueUxv50000', is_latest=True, key='de78115cc476af9422f916ddfbccbfb6/secondary_analysis.h5ad', description='RNAseq data from the heart of a 43-year-old white male', suffix='.h5ad', otype='AnnData', size=705642400, hash='F1poWKDxbz5CZNAbXqVylQ', n_observations=5735, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:19:23 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='8vI4IIOE7A8AF1RQ0000', is_latest=True, key='de78115cc476af9422f916ddfbccbfb6/expr.h5ad', description='RNAseq data from the heart of a 43-year-old white male', suffix='.h5ad', otype='AnnData', size=79395600, hash='Rg1v2dGTPQESV3PGxh2mlw', n_observations=55605, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:19:27 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='vkZ8mAgi8qMoSJ7m0000', is_latest=True, key='9e91d1be412466551533cce5594450cb/raw_expr.h5ad', description='RNAseq data from the heart of a 53-year-old white male', suffix='.h5ad', otype='AnnData', size=34233472, hash='mo4AYpAtS0a3guu_l1NS2g', n_observations=50859, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:19:46 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='Uqb3Q1MqGBsenxlt0000', is_latest=True, key='9e91d1be412466551533cce5594450cb/secondary_analysis.h5ad', description='RNAseq data from the heart of a 53-year-old white male', suffix='.h5ad', otype='AnnData', size=554944013, hash='wr9ydrucLH6lq8Nq-kCNWQ', n_observations=4642, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:19:50 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='FRZV4NNzxD9TQIwu0000', is_latest=True, key='9e91d1be412466551533cce5594450cb/expr.h5ad', description='RNAseq data from the heart of a 53-year-old white male', suffix='.h5ad', otype='AnnData', size=64005968, hash='BEiI0lkHQWsx19KQGmLXmA', n_observations=50859, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:19:54 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='97h75W8lRACemHFT0000', is_latest=True, key='c6bb00096b0cf40751f9d6003fb730c7/raw_expr.h5ad', description='RNAseq data from the heart of a 51-year-old white male', suffix='.h5ad', otype='AnnData', size=48716432, hash='dt7EcuB-scgVZIhF_MfqLA', n_observations=65248, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:20:14 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='UYIXD7oTpyojypXk0000', is_latest=True, key='c6bb00096b0cf40751f9d6003fb730c7/secondary_analysis.h5ad', description='RNAseq data from the heart of a 51-year-old white male', suffix='.h5ad', otype='AnnData', size=878563142, hash='I-PD-5Zzbm6AnCo8cIa43w', n_observations=6904, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:20:19 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='vr6bIRML527tPi8j0000', is_latest=True, key='c6bb00096b0cf40751f9d6003fb730c7/expr.h5ad', description='RNAseq data from the heart of a 51-year-old white male', suffix='.h5ad', otype='AnnData', size=96669168, hash='pj0tKvU1BoYzS3JecxAbgQ', n_observations=65248, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:20:23 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='UkuW3SChdHdlFVSw0000', is_latest=True, key='898138b7f45a67c574e9955fb400e9be/raw_expr.h5ad', description='RNAseq data from the kidney (left) of a 40-year-old white female', suffix='.h5ad', otype='AnnData', size=32304048, hash='3PcS07cemiJ9SRK-LeNYbA', n_observations=4974, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:21:10 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='rtI6kJOAGdPtaeSI0000', is_latest=True, key='898138b7f45a67c574e9955fb400e9be/secondary_analysis.h5ad', description='RNAseq data from the kidney (left) of a 40-year-old white female', suffix='.h5ad', otype='AnnData', size=349536118, hash='Ae9_WmFlWKhK6AftPYSjRw', n_observations=2545, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:21:14 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='NzaOTvzAkTFzGjhf0000', is_latest=True, key='898138b7f45a67c574e9955fb400e9be/expr.h5ad', description='RNAseq data from the kidney (left) of a 40-year-old white female', suffix='.h5ad', otype='AnnData', size=57766952, hash='RyMM7ecv6Bt1p_LaI7xGRA', n_observations=4974, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:21:18 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='AQnLMC70ln9THHZM0000', is_latest=True, key='39d51c436734e5750bf84553ef7eaf85/raw_expr.h5ad', description='RNAseq data from the large intestine of a 37-year-old white male', suffix='.h5ad', otype='AnnData', size=139607648, hash='LxPYz16uAiaA5lmU6iTGEg', n_observations=4434, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:22:05 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='bRsIdX8qm2Dl7opj0000', is_latest=True, key='39d51c436734e5750bf84553ef7eaf85/secondary_analysis.h5ad', description='RNAseq data from the large intestine of a 37-year-old white male', suffix='.h5ad', otype='AnnData', size=1012271077, hash='MXlIuaiETx8bqTcpqMuu3A', n_observations=4429, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:22:09 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='iYaw4ZwGD1ywYdvf0000', is_latest=True, key='39d51c436734e5750bf84553ef7eaf85/expr.h5ad', description='RNAseq data from the large intestine of a 37-year-old white male', suffix='.h5ad', otype='AnnData', size=286580456, hash='k4gadlwFvBwpRiz-Puukvg', n_observations=4434, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:22:12 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='5i6sEG3DSlw55io20000', is_latest=True, key='87e85403e3f7a946fc40bdcf5cba8360/raw_expr.h5ad', description='RNAseq data from the large intestine of a 37-year-old white male', suffix='.h5ad', otype='AnnData', size=103479816, hash='mG6XRE5Gi5IP7qG5z1eAiQ', n_observations=6017, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:20:43 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='xLpZLf3cfqjLFMzz0000', is_latest=True, key='87e85403e3f7a946fc40bdcf5cba8360/secondary_analysis.h5ad', description='RNAseq data from the large intestine of a 37-year-old white male', suffix='.h5ad', otype='AnnData', size=1107837826, hash='3SqEhNy89FAmot70G-SxOg', n_observations=5986, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:20:46 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='SyaC5dZwIQ8eRIIS0000', is_latest=True, key='87e85403e3f7a946fc40bdcf5cba8360/expr.h5ad', description='RNAseq data from the large intestine of a 37-year-old white male', suffix='.h5ad', otype='AnnData', size=212024920, hash='B9IZ2X83Co6lh4Gm39Y3Ig', n_observations=6017, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:20:50 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='QRyogqZsfIsTQyGb0000', is_latest=True, key='266d58d22549461cd454c32084b9f7fe/raw_expr.h5ad', description='RNAseq data from the small intestine of a 37-year-old white male', suffix='.h5ad', otype='AnnData', size=132060080, hash='MZU29uwyvAkDULpNiknPLA', n_observations=3478, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:21:36 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='2YlGVjTiB6MHt7Vh0000', is_latest=True, key='266d58d22549461cd454c32084b9f7fe/secondary_analysis.h5ad', description='RNAseq data from the small intestine of a 37-year-old white male', suffix='.h5ad', otype='AnnData', size=847728326, hash='hQ5GFQfkwcoyvhlhAJnw8g', n_observations=3474, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:21:41 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='e1ZZkhcl2ED8QHey0000', is_latest=True, key='266d58d22549461cd454c32084b9f7fe/expr.h5ad', description='RNAseq data from the small intestine of a 37-year-old white male', suffix='.h5ad', otype='AnnData', size=274040680, hash='sA4SU7QTF1srayMoNBkmkg', n_observations=3478, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:21:45 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='nitDHxekthOOWkQf0000', is_latest=True, key='92248f72d47b916a2027085ec1b8e996/raw_expr.h5ad', description='RNAseq data from the kidney (left) of a 25-year-old white female', suffix='.h5ad', otype='AnnData', size=155091808, hash='QuI9T74Ae7epXIxDmd-cQg', n_observations=19243, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:23:53 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='cSERgXFeTNTfZZA20000', is_latest=True, key='92248f72d47b916a2027085ec1b8e996/secondary_analysis.h5ad', description='RNAseq data from the kidney (left) of a 25-year-old white female', suffix='.h5ad', otype='AnnData', size=2766159124, hash='lxDLg48vwT9QLDWbI7lnNw', n_observations=19242, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:23:56 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='rASTEAXcRXnDwXCA0000', is_latest=True, key='92248f72d47b916a2027085ec1b8e996/expr.h5ad', description='RNAseq data from the kidney (left) of a 25-year-old white female', suffix='.h5ad', otype='AnnData', size=344701496, hash='i8WJydOHDClusuluLOFP8Q', n_observations=19243, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:24:00 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='5UgOO6rroS8IYo6R0000', is_latest=True, key='91cfb45f5d398e950ed65786c87f4372/raw_expr.h5ad', description='RNAseq data from the kidney (right) of a 54-year-old white male', suffix='.h5ad', otype='AnnData', size=33168228, hash='kn_tl7ihCl3F9h9HZ2HhAg', n_observations=2820, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:27:32 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='cGTQ56JCwOQWhEZE0000', is_latest=True, key='91cfb45f5d398e950ed65786c87f4372/secondary_analysis.h5ad', description='RNAseq data from the kidney (right) of a 54-year-old white male', suffix='.h5ad', otype='AnnData', size=359507942, hash='lzXnfx2x1f_AQtUC_2OYZw', n_observations=2752, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:27:36 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='CEKUfRhjKPLpNcUl0000', is_latest=True, key='91cfb45f5d398e950ed65786c87f4372/expr.h5ad', description='RNAseq data from the kidney (right) of a 54-year-old white male', suffix='.h5ad', otype='AnnData', size=60876504, hash='57xYCUpbHGuT0VGX-F4rjw', n_observations=2820, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:27:40 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='8eatyUtNWz2DGhZX0000', is_latest=True, key='be103f95cc6c1a3e48f099d1bd149a49/raw_expr.h5ad', description='RNAseq data from the kidney (left) of a 66-year-old white male', suffix='.h5ad', otype='AnnData', size=223834976, hash='DT0wMdgjf3zhyDthsWN3zw', n_observations=10760, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:32:24 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='hG24w6UV2KwF2ZjL0000', is_latest=True, key='be103f95cc6c1a3e48f099d1bd149a49/secondary_analysis.h5ad', description='RNAseq data from the kidney (left) of a 66-year-old white male', suffix='.h5ad', otype='AnnData', size=2100466334, hash='_fjS8Ai9Pb07dxeqoM7aAg', n_observations=10707, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:32:27 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='YyAVE8NTx12LzhZV0000', is_latest=True, key='be103f95cc6c1a3e48f099d1bd149a49/expr.h5ad', description='RNAseq data from the kidney (left) of a 66-year-old white male', suffix='.h5ad', otype='AnnData', size=496114824, hash='i-u6zCj4p75JMozq-Lkscg', n_observations=10760, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:32:31 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='wXokCmxTuGndMgtA0000', is_latest=True, key='07b9f36478e22bf820ac6a084e01bf94/raw_expr.h5ad', description='RNAseq data from the small intestine of a 78-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=11711504, hash='XfyPTEsaDR9UUc4VBFJtaw', n_observations=206, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:33:18 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='eIJXiHVNnDqO0EP70000', is_latest=True, key='07b9f36478e22bf820ac6a084e01bf94/secondary_analysis.h5ad', description='RNAseq data from the small intestine of a 78-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=35302971, hash='SDYpfMjQyE7U-GuElWsWqQ', n_observations=206, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:33:21 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='Rf5NDWtKlkA2tiEm0000', is_latest=True, key='07b9f36478e22bf820ac6a084e01bf94/expr.h5ad', description='RNAseq data from the small intestine of a 78-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=13362984, hash='cZAte5aPQVcDZ1q1D7NyLQ', n_observations=206, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:33:25 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='80ESQeyrlwpkOiU00000', is_latest=True, key='b23c6f176280ad4c9fe8f74509cb6cf6/raw_expr.h5ad', description='RNAseq data from the small intestine of a 78-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=12025824, hash='PxNsEPGqWkdH0TOmRXrMJw', n_observations=203, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:32:50 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='8NaWjdmBjRVGTY270000', is_latest=True, key='b23c6f176280ad4c9fe8f74509cb6cf6/secondary_analysis.h5ad', description='RNAseq data from the small intestine of a 78-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=37962692, hash='Z0iuS8P5T5-i-DVos0Yj3Q', n_observations=202, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:32:54 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='Kpg5OT18f3d9fs1i0000', is_latest=True, key='b23c6f176280ad4c9fe8f74509cb6cf6/expr.h5ad', description='RNAseq data from the small intestine of a 78-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=14061816, hash='3ZV9P3g-mktKz5tgV_h31g', n_observations=203, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:32:58 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='om7kOQGyELBn074F0000', is_latest=True, key='0a0eb095c8e7f7c890da20184d7527cb/raw_expr.h5ad', description='RNAseq data from the large intestine of a 78-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=69322032, hash='0NwSNhglNzxd8yKsV0m-5g', n_observations=5998, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:33:46 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='4JzsJdn3UKXdp9OE0000', is_latest=True, key='0a0eb095c8e7f7c890da20184d7527cb/secondary_analysis.h5ad', description='RNAseq data from the large intestine of a 78-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=908944296, hash='2vOajaCP1fOnCdgrJeJi0A', n_observations=5928, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:33:50 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='7Vw9yyUDhQToMvRp0000', is_latest=True, key='0a0eb095c8e7f7c890da20184d7527cb/expr.h5ad', description='RNAseq data from the large intestine of a 78-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=137566376, hash='fja6trJCgNvwK9RrV2aapQ', n_observations=5998, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:33:54 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='sRPtKO1FXmqEJduG0000', is_latest=True, key='018a905cdbdff684760859f594d3fd77/raw_expr.h5ad', description='RNAseq data from the kidney (right) of a 75-year-old white female', suffix='.h5ad', otype='AnnData', size=145265888, hash='aBI5GNSKHE_DlA9ratsSfw', n_observations=7999, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:41:54 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='3mqocCclZcaJDJrb0000', is_latest=True, key='018a905cdbdff684760859f594d3fd77/secondary_analysis.h5ad', description='RNAseq data from the kidney (right) of a 75-year-old white female', suffix='.h5ad', otype='AnnData', size=1436877375, hash='xmQnZqKAcaTzUqodN_4ujQ', n_observations=7997, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:41:57 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='ZQIs2Syok6M97hZW0000', is_latest=True, key='018a905cdbdff684760859f594d3fd77/expr.h5ad', description='RNAseq data from the kidney (right) of a 75-year-old white female', suffix='.h5ad', otype='AnnData', size=311622776, hash='ddbo8YIk555aSUBgNhFeOw', n_observations=7999, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:42:01 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='Vyvdl4xzqzl3stlO0000', is_latest=True, key='2638ed2b83e619710497ca2410dc1da1/raw_expr.h5ad', description='RNAseq data from the large intestine of a 37-year-old white male', suffix='.h5ad', otype='AnnData', size=18696392, hash='qGNILVcTyukngkEgWw44sw', n_observations=841, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:46:06 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='116fz8nUXAa0rJeU0000', is_latest=True, key='2638ed2b83e619710497ca2410dc1da1/secondary_analysis.h5ad', description='RNAseq data from the large intestine of a 37-year-old white male', suffix='.h5ad', otype='AnnData', size=119072364, hash='UgywyJ1L0g5T3R5QIh35xg', n_observations=841, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:46:10 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='ciUm7iADJMguw7KD0000', is_latest=True, key='2638ed2b83e619710497ca2410dc1da1/expr.h5ad', description='RNAseq data from the large intestine of a 37-year-old white male', suffix='.h5ad', otype='AnnData', size=28926904, hash='RsCbErFEVrQzmeolZmF_QQ', n_observations=841, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:46:14 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='BNuowI8kC1COjCpb0000', is_latest=True, key='453b06e1f62ec3e54d8380e4e974a5a5/raw_expr.h5ad', description='RNAseq data from the small intestine of a 30-year-old white male', suffix='.h5ad', otype='AnnData', size=259862688, hash='A3ZAhnDuoUNdwZ1ooUPyIA', n_observations=10725, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:42:18 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='7l4ZbwbYUarRDc6t0000', is_latest=True, key='453b06e1f62ec3e54d8380e4e974a5a5/secondary_analysis.h5ad', description='RNAseq data from the small intestine of a 30-year-old white male', suffix='.h5ad', otype='AnnData', size=2237924229, hash='aRzGwa0cPkO66oBVcVW9Qw', n_observations=10699, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:42:22 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='a7xXAWxTcUuKiuKw0000', is_latest=True, key='453b06e1f62ec3e54d8380e4e974a5a5/expr.h5ad', description='RNAseq data from the small intestine of a 30-year-old white male', suffix='.h5ad', otype='AnnData', size=588791512, hash='0i3lrNUAdLshXgLoavlgJw', n_observations=10725, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:42:26 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='R18mrrDQfKi7gaWR0000', is_latest=True, key='9b03c4c79ef7bcd1e8992cd50ed3f482/raw_expr.h5ad', description='RNAseq data from the large intestine of a 54-year-old black or african american female', suffix='.h5ad', otype='AnnData', size=123217608, hash='B6q0sJoalMPoYncC77Tq4w', n_observations=4337, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:42:46 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='Y1rSjrLzrcLFvGdk0000', is_latest=True, key='9b03c4c79ef7bcd1e8992cd50ed3f482/secondary_analysis.h5ad', description='RNAseq data from the large intestine of a 54-year-old black or african american female', suffix='.h5ad', otype='AnnData', size=955437213, hash='8A95v8EsR8s4tflfgS1BuA', n_observations=4329, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:42:50 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='uRYa3IhVHgkZphxA0000', is_latest=True, key='9b03c4c79ef7bcd1e8992cd50ed3f482/expr.h5ad', description='RNAseq data from the large intestine of a 54-year-old black or african american female', suffix='.h5ad', otype='AnnData', size=261415608, hash='27KS4uybFNt7oUqDx4N6qQ', n_observations=4337, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:42:54 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='08d9by7DMeenEmVn0000', is_latest=True, key='67d7b5a3fb4f64a1f714d4369fdedc16/raw_expr.h5ad', description='RNAseq data from the large intestine of a 54-year-old black or african american female', suffix='.h5ad', otype='AnnData', size=105628528, hash='nVgYif7dF6wGBlpUk3dw4A', n_observations=4294, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:43:15 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='RqkM7GPi1ZVbS7pg0000', is_latest=True, key='67d7b5a3fb4f64a1f714d4369fdedc16/secondary_analysis.h5ad', description='RNAseq data from the large intestine of a 54-year-old black or african american female', suffix='.h5ad', otype='AnnData', size=900737049, hash='VTAwXduKf8EPEpVygwareA', n_observations=4285, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:43:19 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='ufv8Po0ZWkXdKmF10000', is_latest=True, key='67d7b5a3fb4f64a1f714d4369fdedc16/expr.h5ad', description='RNAseq data from the large intestine of a 54-year-old black or african american female', suffix='.h5ad', otype='AnnData', size=220375560, hash='5zXjsIiDOFoCDmdfou6qlQ', n_observations=4294, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:43:23 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='CoRBHhQYknxpZEtF0000', is_latest=True, key='4e9a64e657cca28ad36bd2c62693b6e0/raw_expr.h5ad', description='RNAseq data from the large intestine of a 24-year-old white male', suffix='.h5ad', otype='AnnData', size=95880168, hash='o1RypjqqziOdEfhlDm4DGw', n_observations=4300, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:43:45 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='IqJ9HJ21yJrfpU0x0000', is_latest=True, key='4e9a64e657cca28ad36bd2c62693b6e0/secondary_analysis.h5ad', description='RNAseq data from the large intestine of a 24-year-old white male', suffix='.h5ad', otype='AnnData', size=847246581, hash='m3Ib-pAgWKo34kzwhqmUMQ', n_observations=4297, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:43:49 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='79yYfL8E67YCUC6o0000', is_latest=True, key='4e9a64e657cca28ad36bd2c62693b6e0/expr.h5ad', description='RNAseq data from the large intestine of a 24-year-old white male', suffix='.h5ad', otype='AnnData', size=196499400, hash='7PW-YZcuACwcs0zx_kRFIQ', n_observations=4300, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:43:53 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='oKWjKXXEWlgXBAC10000', is_latest=True, key='de1f726e33c439d7683d37401beaea86/raw_expr.h5ad', description='RNAseq data from the knee (left) of a 56-year-old white male', suffix='.h5ad', otype='AnnData', size=171826688, hash='mfM_8GN-38R6gu-FusA0zw', n_observations=10983, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:44:37 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='lRRQtTRMZ7RqUvmD0000', is_latest=True, key='de1f726e33c439d7683d37401beaea86/secondary_analysis.h5ad', description='RNAseq data from the knee (left) of a 56-year-old white male', suffix='.h5ad', otype='AnnData', size=1003686464, hash='boQ1J3K7hy4iVl-S7v7-Nw', n_observations=5725, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:44:41 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='UmyBuyXJBREPAEAr0000', is_latest=True, key='de1f726e33c439d7683d37401beaea86/expr.h5ad', description='RNAseq data from the knee (left) of a 56-year-old white male', suffix='.h5ad', otype='AnnData', size=401622232, hash='Fwd8s90vkSczGmai1E9B9w', n_observations=10983, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:44:45 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='gj1RGLNBtueJ8pOJ0000', is_latest=True, key='f47349f1e0fea69263a8d68c7dac65c5/raw_expr.h5ad', description='RNAseq data from the knee (right) of a 49-year-old white male', suffix='.h5ad', otype='AnnData', size=222823696, hash='A9vOtsegCwia-pPPwTcjuA', n_observations=10987, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:44:11 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='252kWz76BV3zIWFR0000', is_latest=True, key='f47349f1e0fea69263a8d68c7dac65c5/secondary_analysis.h5ad', description='RNAseq data from the knee (right) of a 49-year-old white male', suffix='.h5ad', otype='AnnData', size=1425468486, hash='1L5Mmn4tt8LtGB3RmhdgDg', n_observations=8231, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:44:16 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='Ky9Qpx2SxwPBnCZF0000', is_latest=True, key='f47349f1e0fea69263a8d68c7dac65c5/expr.h5ad', description='RNAseq data from the knee (right) of a 49-year-old white male', suffix='.h5ad', otype='AnnData', size=523729080, hash='KMtda3duLiCZBgdLYUzrAA', n_observations=10987, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:44:20 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='FFJCOjUBxsgT55IK0000', is_latest=True, key='4b3d4efca2e64a650e943c7bf63f9830/raw_expr.h5ad', description='RNAseq data from the bladder of a 25-year-old white male', suffix='.h5ad', otype='AnnData', size=127230608, hash='1d4C_O9OuIoOTG1OSfBl_Q', n_observations=8993, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:45:04 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='HnUebc2xZMAQIGWI0000', is_latest=True, key='4b3d4efca2e64a650e943c7bf63f9830/secondary_analysis.h5ad', description='RNAseq data from the bladder of a 25-year-old white male', suffix='.h5ad', otype='AnnData', size=1513957810, hash='hwZbrmSwvngh3-xU5smHng', n_observations=8983, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:45:08 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='dekKqxxd8iSX8j3f0000', is_latest=True, key='4b3d4efca2e64a650e943c7bf63f9830/expr.h5ad', description='RNAseq data from the bladder of a 25-year-old white male', suffix='.h5ad', otype='AnnData', size=268441816, hash='-z2wmkpwYpVMLmqeK6YbWQ', n_observations=8993, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:45:12 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='KKAVcth2Ql445HaL0000', is_latest=True, key='365d954aadc27b928c1e92a838b952f8/raw_expr.h5ad', description='RNAseq data from the knee (right) of a 27-year-old white female', suffix='.h5ad', otype='AnnData', size=273647104, hash='IxYA8mxURUIowAxRZoxNGA', n_observations=10999, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:45:32 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='up9rxBw63bA5XCyf0000', is_latest=True, key='365d954aadc27b928c1e92a838b952f8/secondary_analysis.h5ad', description='RNAseq data from the knee (right) of a 27-year-old white female', suffix='.h5ad', otype='AnnData', size=1686465008, hash='iWIdpohoy2aStZGkicnz7w', n_observations=9498, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:45:36 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='VrZXRrJwdwSVE79U0000', is_latest=True, key='365d954aadc27b928c1e92a838b952f8/expr.h5ad', description='RNAseq data from the knee (right) of a 27-year-old white female', suffix='.h5ad', otype='AnnData', size=650060024, hash='peFTfTij3xaMlwI6qQpQNw', n_observations=10999, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:45:39 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='fTfcTDPivuYKioAm0000', is_latest=True, key='f9848244883f6c70972acef16680431a/raw_expr.h5ad', description='RNAseq data from the lung (right) of a 37-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=116067008, hash='FSWF5ybb5pWO4UwhN4dhIA', n_observations=8688, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:35:32 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='sQ7geGde74aCHAku0000', is_latest=True, key='f9848244883f6c70972acef16680431a/secondary_analysis.h5ad', description='RNAseq data from the lung (right) of a 37-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=1468982234, hash='cG1KHMzbA6E1GaM0Air9VQ', n_observations=8686, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:35:36 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='vYpxZhFQMLwyJkeE0000', is_latest=True, key='f9848244883f6c70972acef16680431a/expr.h5ad', description='RNAseq data from the lung (right) of a 37-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=237051848, hash='JqAiF06PLnbPECZw9kWi3w', n_observations=8688, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:35:40 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='rmR08r8cPPrMv0JG0000', is_latest=True, key='79f087ae551dd72997f174646bb0d5e0/raw_expr.h5ad', description='RNAseq data from the lung (right) of a 37-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=68570960, hash='YqRiX5H5SdpJIiu9oYP2qA', n_observations=4899, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:39:34 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='jfokyzyV2wLTLIaE0000', is_latest=True, key='79f087ae551dd72997f174646bb0d5e0/secondary_analysis.h5ad', description='RNAseq data from the lung (right) of a 37-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=720025838, hash='ro3nJWvNv3eXjNj4aKWgiQ', n_observations=4251, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:39:38 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='AbBjIJ1jLLDF20cr0000', is_latest=True, key='79f087ae551dd72997f174646bb0d5e0/expr.h5ad', description='RNAseq data from the lung (right) of a 37-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=135999288, hash='1wVslbFxeMnL8IhArwse9w', n_observations=4899, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:39:42 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='H2sTd908aJL1idzt0000', is_latest=True, key='4706e0339d507e7bd878458e2e9e7460/raw_expr.h5ad', description='RNAseq data from the liver of a 21-year-old white male', suffix='.h5ad', otype='AnnData', size=14917184, hash='8hdgaI9iMMIWScZC_B4StA', n_observations=255, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:40:00 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='FEAADaxDHVRlezTA0000', is_latest=True, key='4706e0339d507e7bd878458e2e9e7460/secondary_analysis.h5ad', description='RNAseq data from the liver of a 21-year-old white male', suffix='.h5ad', otype='AnnData', size=41430104, hash='O2EUdRGXuEbQbYPU90b6LQ', n_observations=250, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:40:04 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='GexePm2mFu7ML3KL0000', is_latest=True, key='4706e0339d507e7bd878458e2e9e7460/expr.h5ad', description='RNAseq data from the liver of a 21-year-old white male', suffix='.h5ad', otype='AnnData', size=21793112, hash='GNVOCUb3db88p3004zXVyg', n_observations=255, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:40:08 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='6lqJKWxSudCWY6Er0000', is_latest=True, key='d6e6c8e452ed628425e9e928306a6db0/raw_expr.h5ad', description='RNAseq data from the heart of a 45-year-old white male', suffix='.h5ad', otype='AnnData', size=48929616, hash='-6B-Noc90hc-09yaKbaG2Q', n_observations=60348, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:41:25 UTC); to track this artifact as an input, use: ln.Artifact.get()
# → returning existing artifact with same hash: Artifact(uid='bJPCbAJrCAW23Vk60000', is_latest=True, key='d6e6c8e452ed628425e9e928306a6db0/secondary_analysis.h5ad', description='RNAseq data from the heart of a 45-year-old white male', suffix='.h5ad', otype='AnnData', size=916565672, hash='WvMGGt7VH2TonzHirAZ1GA', n_observations=7565, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 14:41:29 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ...
# ! updated description from RNAseq data from the knee (right) of a 24.0-year-old unknown male to RNAseq data from the knee (right) of a 24-year-old unknown male
# → returning existing artifact with same hash: Artifact(uid='vD6hnmSapKDNbIMt0000', is_latest=True, key='d67c61063b82f6479e93133bdd8949fb/raw_expr.h5ad', description='RNAseq data from the bladder of a 43.0-year-old white male', suffix='.h5ad', otype='AnnData', size=309431504, hash='RwyC7lOZNpc8Y6TT-Vfr6Q', n_observations=16000, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-29 11:11:12 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ! updated description from RNAseq data from the bladder of a 43.0-year-old white male to RNAseq data from the bladder of a 43-year-old white male
# → returning existing artifact with same hash: Artifact(uid='BLrNbcIx6fRrCoqh0000', is_latest=True, key='d67c61063b82f6479e93133bdd8949fb/secondary_analysis.h5ad', description='RNAseq data from the bladder of a 43.0-year-old white male', suffix='.h5ad', otype='AnnData', size=3216671445, hash='91Ow-7Jgv10hBphK2xO1pA', n_observations=15993, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-29 11:11:15 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ! updated description from RNAseq data from the bladder of a 43.0-year-old white male to RNAseq data from the bladder of a 43-year-old white male
# → returning existing artifact with same hash: Artifact(uid='6L1fCm9KyU7loSRs0000', is_latest=True, key='d67c61063b82f6479e93133bdd8949fb/expr.h5ad', description='RNAseq data from the bladder of a 43.0-year-old white male', suffix='.h5ad', otype='AnnData', size=684765832, hash='ghko_O4Qwd_lfQ_6Kk3OWw', n_observations=16000, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-29 11:11:18 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ! updated description from RNAseq data from the bladder of a 43.0-year-old white male to RNAseq data from the bladder of a 43-year-old white male
# → returning existing artifact with same hash: Artifact(uid='rTKIUr5ifuv5BlO20000', is_latest=True, key='6cd63d0ee2c67c3be41e4be1522d9c07/raw_expr.h5ad', description='RNAseq data from the kidney (left) of a 76.0-year-old white male', suffix='.h5ad', otype='AnnData', size=97665232, hash='ozi4j8BgYs7t1pNH-twqNw', n_observations=7742, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 16:30:49 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ! updated description from RNAseq data from the kidney (left) of a 76.0-year-old white male to RNAseq data from the kidney (left) of a 76-year-old white male
# → returning existing artifact with same hash: Artifact(uid='JyNMq1iokAHPHIge0000', is_latest=True, key='6cd63d0ee2c67c3be41e4be1522d9c07/secondary_analysis.h5ad', description='RNAseq data from the kidney (left) of a 76.0-year-old white male', suffix='.h5ad', otype='AnnData', size=1142018474, hash='8RbojbBpdwq2J9YGrKuf_w', n_observations=6570, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 16:30:52 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ! updated description from RNAseq data from the kidney (left) of a 76.0-year-old white male to RNAseq data from the kidney (left) of a 76-year-old white male
# → returning existing artifact with same hash: Artifact(uid='gHiT9vv6SyfBlczM0000', is_latest=True, key='6cd63d0ee2c67c3be41e4be1522d9c07/expr.h5ad', description='RNAseq data from the kidney (left) of a 76.0-year-old white male', suffix='.h5ad', otype='AnnData', size=197293576, hash='ngB7p7H_6Vs_ervilKKWFw', n_observations=7742, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 16:30:56 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ! updated description from RNAseq data from the kidney (left) of a 76.0-year-old white male to RNAseq data from the kidney (left) of a 76-year-old white male
# → returning existing artifact with same hash: Artifact(uid='dEM0OrJocY1drVUA0000', is_latest=True, key='aaedb5272190e61bf557d3b0a1bc591f/raw_expr.h5ad', description='RNAseq data from the kidney (right) of a 29.0-year-old white male', suffix='.h5ad', otype='AnnData', size=18259360, hash='vlNgQapIooBQ_ZCR9Jv8Qw', n_observations=501, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-28 16:31:11 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ! updated description from RNAseq data from the kidney (right) of a 29.0-year-old white male to RNAseq data from the kidney (right) of a 29-year-old white male
# → returning existing artifact with same hash: Artifact(uid='dXBYYgEdv2lK4g3C0000', is_latest=True, key='aaedb5272190e61bf557d3b0a1bc591f/secondary_analysis.h5ad', description='RNAseq data from the kidney (right) of a 29.0-year-old white male', suffix='.h5ad', otype='AnnData', size=78693643, hash='vF7BugXklJTZ-uh0sUamLA', n_observations=382, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-29 11:02:39 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ! updated description from RNAseq data from the kidney (right) of a 29.0-year-old white male to RNAseq data from the kidney (right) of a 29-year-old white male
# → returning existing artifact with same hash: Artifact(uid='gdu9od7z2HQWtbEq0000', is_latest=True, key='aaedb5272190e61bf557d3b0a1bc591f/expr.h5ad', description='RNAseq data from the kidney (right) of a 29.0-year-old white male', suffix='.h5ad', otype='AnnData', size=27748784, hash='uWH9BgtpIpt_hHbnhZn_7w', n_observations=501, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-29 11:02:42 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ! updated description from RNAseq data from the kidney (right) of a 29.0-year-old white male to RNAseq data from the kidney (right) of a 29-year-old white male
# → returning existing artifact with same hash: Artifact(uid='FDBeaRMvyhMTxRHb0000', is_latest=True, key='3bb5f743b039cb620d7ef234e0876f7a/raw_expr.h5ad', description='RNAseq data from the kidney (right) of a 29.0-year-old white male', suffix='.h5ad', otype='AnnData', size=110000320, hash='R5NS-xVkC6ULH5TEgWTClg', n_observations=6410, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-29 11:02:56 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ! updated description from RNAseq data from the kidney (right) of a 29.0-year-old white male to RNAseq data from the kidney (right) of a 29-year-old white male
# → returning existing artifact with same hash: Artifact(uid='lT7LUpMGTE1PQoZA0000', is_latest=True, key='3bb5f743b039cb620d7ef234e0876f7a/secondary_analysis.h5ad', description='RNAseq data from the kidney (right) of a 29.0-year-old white male', suffix='.h5ad', otype='AnnData', size=1089665537, hash='DF4ukuGehIST3SiLpvsajQ', n_observations=5932, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-29 11:02:59 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ! updated description from RNAseq data from the kidney (right) of a 29.0-year-old white male to RNAseq data from the kidney (right) of a 29-year-old white male
# → returning existing artifact with same hash: Artifact(uid='mIfzdO5ODUIuNSPi0000', is_latest=True, key='3bb5f743b039cb620d7ef234e0876f7a/expr.h5ad', description='RNAseq data from the kidney (right) of a 29.0-year-old white male', suffix='.h5ad', otype='AnnData', size=223855336, hash='AgxmLxfucMo6NB9v_CyHdg', n_observations=6410, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-29 11:03:02 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ! updated description from RNAseq data from the kidney (right) of a 29.0-year-old white male to RNAseq data from the kidney (right) of a 29-year-old white male
# → returning existing artifact with same hash: Artifact(uid='I6Y2BVtz7I3SZLXQ0000', is_latest=True, key='ed630484e46ea49b319c0e1f92140059/raw_expr.h5ad', description='RNAseq data from the lung (right) of a 37.0-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=250894480, hash='yamgYzg5ZOVk7yHspK5Pmg', n_observations=11236, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-29 11:04:23 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ! updated description from RNAseq data from the lung (right) of a 37.0-year-old black or african american male to RNAseq data from the lung (right) of a 37-year-old black or african american male
# → returning existing artifact with same hash: Artifact(uid='HADsEVeNoNjHSheK0000', is_latest=True, key='ed630484e46ea49b319c0e1f92140059/secondary_analysis.h5ad', description='RNAseq data from the lung (right) of a 37.0-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=2345455289, hash='_UTTunn4Dk2hgeLX3vVsaw', n_observations=11208, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-29 11:04:25 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ! updated description from RNAseq data from the lung (right) of a 37.0-year-old black or african american male to RNAseq data from the lung (right) of a 37-year-old black or african american male
# → returning existing artifact with same hash: Artifact(uid='duatvv9Sjzlt5n6c0000', is_latest=True, key='ed630484e46ea49b319c0e1f92140059/expr.h5ad', description='RNAseq data from the lung (right) of a 37.0-year-old black or african american male', suffix='.h5ad', otype='AnnData', size=539123400, hash='_EC8dBytgy0MdP5KWc5HDw', n_observations=11236, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-29 11:04:29 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ! updated description from RNAseq data from the lung (right) of a 37.0-year-old black or african american male to RNAseq data from the lung (right) of a 37-year-old black or african american male
# → returning existing artifact with same hash: Artifact(uid='JTf5Cc0zgOKlsMg70000', is_latest=True, key='0e184744c4443f859984bbd3b7e95d24/raw_expr.h5ad', description='RNAseq data from the liver of a 65.0-year-old white male', suffix='.h5ad', otype='AnnData', size=10151424, hash='3PCD7vkWPYjTzmrj1nwHyA', n_observations=205, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-29 11:06:11 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ! updated description from RNAseq data from the liver of a 65.0-year-old white male to RNAseq data from the liver of a 65-year-old white male
# → returning existing artifact with same hash: Artifact(uid='NQ9qtQX98gyZgLdl0000', is_latest=True, key='0e184744c4443f859984bbd3b7e95d24/secondary_analysis.h5ad', description='RNAseq data from the liver of a 65.0-year-old white male', suffix='.h5ad', otype='AnnData', size=17245347, hash='-DiBDTnV4xCCUvENehd2jA', n_observations=205, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-29 11:06:14 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ! updated description from RNAseq data from the liver of a 65.0-year-old white male to RNAseq data from the liver of a 65-year-old white male
# → returning existing artifact with same hash: Artifact(uid='MbYVDqEU1QH9vGcQ0000', is_latest=True, key='0e184744c4443f859984bbd3b7e95d24/expr.h5ad', description='RNAseq data from the liver of a 65.0-year-old white male', suffix='.h5ad', otype='AnnData', size=10705944, hash='B3O3FJlw_skVNaJKmfH1gQ', n_observations=205, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-29 11:06:17 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ! updated description from RNAseq data from the liver of a 65.0-year-old white male to RNAseq data from the liver of a 65-year-old white male
# → returning existing artifact with same hash: Artifact(uid='skKkqQjXSoVGETYg0000', is_latest=True, key='b1ac71625c1aba9d819fae1725c27a42/raw_expr.h5ad', description='RNAseq data from the heart of a 45.0-year-old white male', suffix='.h5ad', otype='AnnData', size=34207328, hash='OKERRTNC_KPyxO31irHuVg', n_observations=49449, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-29 11:06:31 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ! updated description from RNAseq data from the heart of a 45.0-year-old white male to RNAseq data from the heart of a 45-year-old white male
# → returning existing artifact with same hash: Artifact(uid='ohnEGt13RbvkroLH0000', is_latest=True, key='b1ac71625c1aba9d819fae1725c27a42/secondary_analysis.h5ad', description='RNAseq data from the heart of a 45.0-year-old white male', suffix='.h5ad', otype='AnnData', size=510076038, hash='byP3BjHLKM_ygTaiqHHe8w', n_observations=4419, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-29 11:06:34 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ! updated description from RNAseq data from the heart of a 45.0-year-old white male to RNAseq data from the heart of a 45-year-old white male
# → returning existing artifact with same hash: Artifact(uid='pAhJsII72y0LSlfC0000', is_latest=True, key='b1ac71625c1aba9d819fae1725c27a42/expr.h5ad', description='RNAseq data from the heart of a 45.0-year-old white male', suffix='.h5ad', otype='AnnData', size=64341776, hash='mIO-mjwZWL2KjG1gjSYsRA', n_observations=49449, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-29 11:06:37 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ! updated description from RNAseq data from the heart of a 45.0-year-old white male to RNAseq data from the heart of a 45-year-old white male
# → returning existing artifact with same hash: Artifact(uid='Vn8fpaiMRqn6to260000', is_latest=True, key='d9780d3f4eb9edfe275abaa32ff8633b/raw_expr.h5ad', description='RNAseq data from the spleen of a 21.0-year-old black or african american female', suffix='.h5ad', otype='AnnData', size=161957424, hash='DDTcicqTW_gn2PEdhCf46Q', n_observations=11633, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-29 11:06:52 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ! updated description from RNAseq data from the spleen of a 21.0-year-old black or african american female to RNAseq data from the spleen of a 21-year-old black or african american female
# → returning existing artifact with same hash: Artifact(uid='7jBPdth174dfUnpB0000', is_latest=True, key='d9780d3f4eb9edfe275abaa32ff8633b/secondary_analysis.h5ad', description='RNAseq data from the spleen of a 21.0-year-old black or african american female', suffix='.h5ad', otype='AnnData', size=1195152230, hash='QaPYk8p57IhlAgfva7i_2A', n_observations=9519, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-29 11:06:55 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ! updated description from RNAseq data from the spleen of a 21.0-year-old black or african american female to RNAseq data from the spleen of a 21-year-old black or african american female
# → returning existing artifact with same hash: Artifact(uid='IddX4Mz3inkP5fQ60000', is_latest=True, key='d9780d3f4eb9edfe275abaa32ff8633b/expr.h5ad', description='RNAseq data from the spleen of a 21.0-year-old black or african american female', suffix='.h5ad', otype='AnnData', size=359408728, hash='6ZAHOXa0XwlWPPFLcB1yeA', n_observations=11633, space_id=1, storage_id=2, run_id=11, created_by_id=3, created_at=2025-01-29 11:06:58 UTC); to track this artifact as an input, use: ln.Artifact.get()
# ! updated description from RNAseq data from the spleen of a 21.0-year-old black or african american female to RNAseq data from the spleen of a 21-year-old black or african american female

# %%
ln.finish()
# Out:
# • please hit CMD + s to save the notebook in your editor  ✓
# ! cells [(0, None), (None, 2)] were not run consecutively
# → finished Run('9wCIRsb1') after 1h at 2025-05-21 12:39:12 UTC
# → go to: https://lamin.ai/laminlabs/hubmap/transform/WrlPTZWhrZZP0002
# → to update your notebook from the CLI, run: lamin save /Users/altananamsaraeva/Desktop/Lamin/hubmap-registration/scrna/register-single-cell-rna.ipynb
