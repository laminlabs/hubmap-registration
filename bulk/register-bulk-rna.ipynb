# %% [markdown]
# # Register Bulk RNA

# %%
import lamindb as ln
import bionty as bt
import wetlab as wl
# Out:
# → connected lamindb: laminlabs/hubmap

# %%
ln.track()
# Out:
# → created Transform('uZfw94bwLkfO0000'), started new Run('PGXTm5QW...') at 2025-05-21 13:47:29 UTC
# → notebook imports: lamindb==1.5.3 pandas==2.2.3
# • recommendation: to identify the notebook across renames, pass the uid: ln.track("uZfw94bwLkfO")

# %%
# Corresponds to the curated metadata not the raw API output
metadata = ln.Artifact.get("ajd285FK90Z0ZBN10003").load()

# %%
metadata.head()
# Out:
#                                uuid                           assay  \
# 0  2c77b1cdf33dbed3dbfb74e4b578300e                NEBNext Ultra II
# 1  f84c8edc36a65f248c2649ebbe52ad35                NEBNext Ultra II
# 2  311837bf483627cc967e40092a251096                NEBNext Ultra II
# 3  c67e024e8fcc25166aac2e2e883208df  KAPA RNA HyperPrep + RiboErase
# 4  73507265c43d750e6ec5e48d1e2e0b92  KAPA RNA HyperPrep + RiboErase
#
#                      rnaseq_assay_method  \
# 0  NEBNext Ultra II RNA Library Prep Kit
# 1  NEBNext Ultra II RNA Library Prep Kit
# 2  NEBNext Ultra II RNA Library Prep Kit
# 3  KAPA RNA HyperPrep Kit with RiboErase
# 4  KAPA RNA HyperPrep Kit with RiboErase
#
#                                                title  \
# 0  RNAseq data from the large intestine of a 67-y...
# 1  RNAseq data from the large intestine of a 67-y...
# 2  RNAseq data from the small intestine of a 67-y...
# 3  RNAseq data from the placenta of a 34-year-old...
# 4  RNAseq data from the placenta of a 34-year-old...
#
#                                           group_name consortium  \
# 0                                       Stanford TMC     HuBMAP
# 1                                       Stanford TMC     HuBMAP
# 2                                       Stanford TMC     HuBMAP
# 3  TMC - University of California San Diego focus...     HuBMAP
# 4  TMC - University of California San Diego focus...     HuBMAP
#
#                         doi publication_date     status dataset_type  \
# 0  10.35079/HBM756.GJDX.884       2020-08-22  protected       RNAseq
# 1  10.35079/HBM454.ZWSD.895       2020-08-22  protected       RNAseq
# 2  10.35079/HBM656.ZCCL.743       2020-08-22  protected       RNAseq
# 3  10.35079/HBM669.BFZR.956       2025-02-26  protected       RNAseq
# 4  10.35079/HBM765.RPVQ.584       2025-02-26  protected       RNAseq
#
#   processing organ sample_category analyte_class   bmi age ethnicity      sex  \
# 0        raw    LI           block           RNA  30.2  67  European   female
# 1        raw    LI           block           RNA  30.2  67  European   female
# 2        raw    SI           block           RNA  30.2  67  European   female
# 3        raw    PL           block           RNA                  na  unknown
# 4        raw    PL           block           RNA                  na  unknown
#
#                                             diseases         donor_id  \
# 0  [hypertensive disorder, coronary artery disord...  HBM279.WPZP.978
# 1  [hypertensive disorder, coronary artery disord...  HBM279.WPZP.978
# 2  [hypertensive disorder, coronary artery disord...  HBM279.WPZP.978
# 3                                           [normal]  HBM683.TPQL.293
# 4                                           [normal]  HBM864.XRGJ.897
#
#          sample_id                       ancestor_id  \
# 0  HBM488.XJKW.383  d0cb764459fd1d1c6f04fdce2e982831
# 1  HBM875.RVTT.868  3d742332ef8ca26f34f7ee5b9da3381c
# 2  HBM229.NKWB.488  35e16f13caab262f446836f63cf4ad42
# 3  HBM265.XLDG.695  0236e72a6ce04abc0008ac2a40cf1b35
# 4  HBM464.GLHP.566  c97c86db1d6c7f62445c06d70289c87a
#
#                              expression_matrices_url           tissue  \
# 0  https://assets.hubmapconsortium.org/9e7b040f23...  large intestine
# 1  https://assets.hubmapconsortium.org/1c141b1558...  large intestine
# 2  https://assets.hubmapconsortium.org/a8a603e704...  small intestine
# 3  https://assets.hubmapconsortium.org/7d7ba54632...         placenta
# 4  https://assets.hubmapconsortium.org/fc80dbe141...         placenta
#
#   suspension_type tissue_type
# 0            bulk      tissue
# 1            bulk      tissue
# 2            bulk      tissue
# 3            bulk      tissue
# 4            bulk      tissue

# %%
from fsspec.asyn import FSTimeoutError

for idx, row in metadata.iterrows():
    ds = row.to_dict()

    try:
        # Some rows do not have URLs. These are high level dataset views that may have metadata.
        artifacts = []

        if expr_url := ds["expression_matrices_url"]:
            expr_af = ln.Artifact(expr_url, description=f"{ds['title']}").save()
            expr_af.ulabels.add(ln.ULabel.filter(name="expr_bulk").one())
            artifacts.append(expr_af)

            expr_af.references.add(ln.Reference.filter(doi=ds["doi"]).one())
            expr_af.tissues.add(bt.Tissue.filter(name=ds["tissue"]).one())
            expr_af.ethnicities.add(bt.Ethnicity.filter(name=ds["ethnicity"]).one())
            expr_af.phenotypes.add(bt.Phenotype.filter(name=ds["sex"]).one())

            for disease_name in ds["diseases"]:
                expr_af.diseases.add(bt.Disease.filter(name=disease_name).one())

            expr_af.ulabels.add(ln.ULabel.filter(name=ds["suspension_type"]).one())
            expr_af.experimental_factors.add(
                bt.ExperimentalFactor.filter(name=ds["assay"]).one()
            )
            expr_af.donors.add(wl.Donor.filter(name=ds["donor_id"]).one())
            expr_af.biosamples.add(wl.Biosample.filter(name=ds["sample_id"]).one())
            expr_af.ulabels.add(ln.ULabel.filter(name="tissue").one())

        ds_cl = ln.Collection.filter(key=ds["uuid"]).one_or_none()

        if ds_cl:
            ds_cl.artifacts.add(*artifacts)
        elif artifacts:
            ds_cl = ln.Collection(
                artifacts, key=ds["uuid"], description=ds["title"]
            ).save()
    except FSTimeoutError:
        print(f"Timeout error for: {ds['title']} of collection UUID {ds['uuid']}")
        continue

# %%
ln.finish()
# Out:
# • please hit CMD + s to save the notebook in your editor  ✓
# → finished Run('PGXTm5QW') after 1h at 2025-05-21 14:58:17 UTC
# → go to: https://lamin.ai/laminlabs/hubmap/transform/uZfw94bwLkfO0000
# → to update your notebook from the CLI, run: lamin save /Users/altananamsaraeva/Desktop/Lamin/hubmap-registration/bulk/register-bulk-rna.ipynb
