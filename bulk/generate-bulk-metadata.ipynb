# %% [markdown]
# # Generate bulk RNA metadata table

# %%
import os
import sys

sys.path.append(os.path.abspath("../"))

import pandas as pd
import lamindb as ln

from query import create_hubmap_metadata_df, BulkseqDataset

assert ln.setup.settings.instance.slug == "laminlabs/hubmap"
# Out:
# → connected lamindb: laminlabs/hubmap

# %%
ln.track()
# Out:
# → loaded Transform('0R8HzkUaLFvQ0002'), re-started Run('gZNU3EkS...') at 2025-05-13 13:51:26 UTC
# → notebook imports: lamindb==1.4.0 pandas==2.2.3 query

# %%
df = pd.read_csv(
    ln.Artifact.using("laminlabs/hubmap").get("9G4UaeVKSY0zy7SX0001").cache(), sep="\t"
)

# Include all assays here for which we want to get metadata information
bulk_assays = [
    "bulk RNA",
    "bulk-RNA",
]

# %%
bulk_metadata_df = create_hubmap_metadata_df(
    df,
    file_types=[
        "expression_matrices.h5",
    ],
    dataset_class=BulkseqDataset,
    assay_filter=bulk_assays,
)
bulk_metadata_df
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 uuid     assay  \
# 0   2c77b1cdf33dbed3dbfb74e4b578300e  bulk RNA
# 1   f84c8edc36a65f248c2649ebbe52ad35  bulk RNA
# 2   311837bf483627cc967e40092a251096  bulk RNA
# 3   c67e024e8fcc25166aac2e2e883208df  bulk-RNA
# 4   73507265c43d750e6ec5e48d1e2e0b92  bulk-RNA
# ..                               ...       ...
# 75  c0793a20fabf88133ada53963ba55350  bulk-RNA
# 76  34a2e913183f1a7487d47380032aa961  bulk-RNA
# 77  cad68e5e910ca90bda79cc0d6aa586d1  bulk-RNA
# 78  16fa3bd20ca6920aa32259022994c5b0  bulk-RNA
# 79  2a6b290836e82bcaf83f1d41990616c2  bulk-RNA
#
#                       rnaseq_assay_method  \
# 0   NEBNext Ultra II RNA Library Prep Kit
# 1   NEBNext Ultra II RNA Library Prep Kit
# 2   NEBNext Ultra II RNA Library Prep Kit
# 3   KAPA RNA HyperPrep Kit with RiboErase
# 4   KAPA RNA HyperPrep Kit with RiboErase
# ..                                    ...
# 75  KAPA RNA HyperPrep Kit with RiboErase
# 76  KAPA RNA HyperPrep Kit with RiboErase
# 77  KAPA RNA HyperPrep Kit with RiboErase
# 78  KAPA RNA HyperPrep Kit with RiboErase
# 79  KAPA RNA HyperPrep Kit with RiboErase
#
#                                                 title  \
# 0   RNAseq data from the large intestine of a 67-y...
# 1   RNAseq data from the large intestine of a 67-y...
# 2   RNAseq data from the small intestine of a 67-y...
# 3   RNAseq data from the placenta of a 34-year-old...
# 4   RNAseq data from the placenta of a 34-year-old...
# ..                                                ...
# 75  RNAseq data from the placenta of a 31-year-old...
# 76  RNAseq data from the placenta of a 31-year-old...
# 77  RNAseq data from the placenta of a 30-year-old...
# 78  RNAseq data from the placenta of a 35-year-old...
# 79  RNAseq data from the placenta of a 35-year-old...
#
#                                            group_name consortium  \
# 0                                        Stanford TMC     HuBMAP
# 1                                        Stanford TMC     HuBMAP
# 2                                        Stanford TMC     HuBMAP
# 3   TMC - University of California San Diego focus...     HuBMAP
# 4   TMC - University of California San Diego focus...     HuBMAP
# ..                                                ...        ...
# 75  TMC - University of California San Diego focus...     HuBMAP
# 76  TMC - University of California San Diego focus...     HuBMAP
# 77  TMC - University of California San Diego focus...     HuBMAP
# 78  TMC - University of California San Diego focus...     HuBMAP
# 79  TMC - University of California San Diego focus...     HuBMAP
#
#                          doi publication_date     status dataset_type  \
# 0   10.35079/HBM756.GJDX.884       2020-08-22  protected       RNAseq
# 1   10.35079/HBM454.ZWSD.895       2020-08-22  protected       RNAseq
# 2   10.35079/HBM656.ZCCL.743       2020-08-22  protected       RNAseq
# 3   10.35079/HBM669.BFZR.956       2025-02-26  protected       RNAseq
# 4   10.35079/HBM765.RPVQ.584       2025-02-26  protected       RNAseq
# ..                       ...              ...        ...          ...
# 75  10.35079/HBM699.ZVNG.629       2025-02-26  protected       RNAseq
# 76  10.35079/HBM652.WSKR.343       2025-02-26  protected       RNAseq
# 77  10.35079/HBM549.BBBQ.445       2025-02-26  protected       RNAseq
# 78  10.35079/HBM554.ZSNK.294       2025-02-26  protected       RNAseq
# 79  10.35079/HBM665.LSQC.339       2025-02-26  protected       RNAseq
#
#    processing organ sample_category analyte_class   bmi age ethnicity     sex  \
# 0         raw    LI           block           RNA  30.2  67     White  Female
# 1         raw    LI           block           RNA  30.2  67     White  Female
# 2         raw    SI           block           RNA  30.2  67     White  Female
# 3         raw    PL           block           RNA
# 4         raw    PL           block           RNA
# ..        ...   ...             ...           ...   ...  ..       ...     ...
# 75        raw    PL           block           RNA
# 76        raw    PL           block           RNA
# 77        raw    PL           block           RNA
# 78        raw    PL           block           RNA
# 79        raw    PL           block           RNA
#
#                                              diseases         donor_id  \
# 0   [Hypertension, Coronary Artery Disease, Cardia...  HBM279.WPZP.978
# 1   [Hypertension, Coronary Artery Disease, Cardia...  HBM279.WPZP.978
# 2   [Hypertension, Coronary Artery Disease, Cardia...  HBM279.WPZP.978
# 3                                            [normal]  HBM683.TPQL.293
# 4                                            [normal]  HBM864.XRGJ.897
# ..                                                ...              ...
# 75                                           [normal]  HBM775.JDDD.365
# 76                                           [normal]  HBM775.JDDD.365
# 77                                           [normal]  HBM635.WSMC.463
# 78                                           [normal]  HBM989.SWJP.679
# 79                                           [normal]  HBM989.SWJP.679
#
#           sample_id                       ancestor_id  \
# 0   HBM488.XJKW.383  d0cb764459fd1d1c6f04fdce2e982831
# 1   HBM875.RVTT.868  3d742332ef8ca26f34f7ee5b9da3381c
# 2   HBM229.NKWB.488  35e16f13caab262f446836f63cf4ad42
# 3   HBM265.XLDG.695  0236e72a6ce04abc0008ac2a40cf1b35
# 4   HBM464.GLHP.566  c97c86db1d6c7f62445c06d70289c87a
# ..              ...                               ...
# 75  HBM442.RZLD.848  88aaa8a785e4ca9adcf1e91e0f4f6e2c
# 76  HBM755.BGWJ.457  5877befa123aa9820159ade8a1bd556f
# 77  HBM582.MSJK.752  68c57420822f7b10d2502fba61ccc02f
# 78  HBM446.RBTR.472  2aaf73824d7dacb4047c3b82684240f3
# 79  HBM595.FHNC.286  f5aee3d9760678007fdb7b97ca4ca2db
#
#                               expression_matrices_url
# 0   https://assets.hubmapconsortium.org/9e7b040f23...
# 1   https://assets.hubmapconsortium.org/1c141b1558...
# 2   https://assets.hubmapconsortium.org/a8a603e704...
# 3   https://assets.hubmapconsortium.org/7d7ba54632...
# 4   https://assets.hubmapconsortium.org/fc80dbe141...
# ..                                                ...
# 75  https://assets.hubmapconsortium.org/9c7ee9633d...
# 76  https://assets.hubmapconsortium.org/00b7898d06...
# 77  https://assets.hubmapconsortium.org/12c79d9141...
# 78  https://assets.hubmapconsortium.org/f66fc48f8d...
# 79  https://assets.hubmapconsortium.org/e8179e513d...
#
# [80 rows x 23 columns]

# %%
bulk_af = ln.Artifact.from_df(
    bulk_metadata_df,
    key="hubmap_metadata/meta_bulkrna_original.parquet",
    description="Bulk RNA metadata information to use for ingestion.",
).save()
# Out:
# → creating new artifact version for key='hubmap_metadata/meta_bulkrna_original.parquet' (storage: 's3://lamin-us-west-2/sznqFqn7xUoI')
# ... uploading j5RQEPmtKuTeo0lO0002.parquet: 100.0%
# ! replacing the existing cache path /Users/altananamsaraeva/Library/Caches/lamindb/lamin-us-west-2/sznqFqn7xUoI/hubmap_metadata/meta_bulkrna_original.parquet

# %%
ln.finish()
# Out:
# • please hit CMD + s to save the notebook in your editor .... still waiting .....
# ......... ✓
# ! returning transform with same hash: Transform(uid='0R8HzkUaLFvQ0001', is_latest=False, key='generate-bulk-metadata.ipynb', description='Generate bulk RNA metadata table', type='notebook', hash='0NX4TAjfoTAuQoaLA1uTnw', space_id=1, created_by_id=5, created_at=2025-05-12 12:23:32 UTC)
# → finished Run('gZNU3EkS') after 2m at 2025-05-13 13:54:07 UTC
# → go to: https://lamin.ai/laminlabs/hubmap/transform/0R8HzkUaLFvQ0001
# → to update your notebook from the CLI, run: lamin save /Users/altananamsaraeva/Desktop/Lamin/hubmap-registration/bulk/generate-bulk-metadata.ipynb
